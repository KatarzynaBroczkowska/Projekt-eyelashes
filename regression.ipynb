# %% [markdown]
# # Model training

# %%
import pandas as pd
import geopandas as gpd
from pysal.model import spreg
import pickle
import string
import re
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
# Out:
# d:\2sem\pdp\.venv\lib\site-packages\spaghetti\network.py:40: FutureWarning: The next major release of pysal/spaghetti (2.0.0) will drop support for all ``libpysal.cg`` geometries. This change is a first step in refactoring ``spaghetti`` that is expected to result in dramatically reduced runtimes for network instantiation and operations. Users currently requiring network and point pattern input as ``libpysal.cg`` geometries should prepare for this simply by converting to ``shapely`` geometries.
#   warnings.warn(dep_msg, FutureWarning, stacklevel=1)

# %% [markdown]
# ## Wczytanie danych

# %%
df_laminacja = pickle.load(open('data.pkl', 'rb'))
df_laminacja.head(2)
# Out:
#                         Description Duration  \
# 0  Laminacja rzęs /farbka ANASTASIA       1g
# 1       Laminacja rzęs /farbka Liza       1g
#
#                                     Location  Price  \
# 0  Aleje Jerozolimskie 107, 02-011, Warszawa  168.0
# 1  Aleje Jerozolimskie 107, 02-011, Warszawa  160.0
#
#                        geometry
# 0  POINT (20.9949283 52.225992)
# 1  POINT (20.9949283 52.225992)

# %%
df_hybrydy = pickle.load(open('data_hybrid.pkl', 'rb'))
df_hybrydy.head(2)
# Out:
#                        Description Duration  \
# 0               Manicure hybrydowy       2g
# 1  Manicure hybrydowy+ baby boomer       3g
#
#                                             Location  Price  \
# 0  Generała Władysława Sikorskiego 14, 09-410, Płock  120.0
# 1  Generała Władysława Sikorskiego 14, 09-410, Płock  170.0
#
#                         geometry
# 0  POINT (19.7551731 52.5378894)
# 1  POINT (19.7551731 52.5378894)

# %% [markdown]
# ## Preproc danych

# %%
def preprocess_text(text):
    text = text.lower()
    text = text.replace('+', ' ')
    text = text.replace('/',' ')
    text = text.replace('🔥', ' ')
    text = text.translate(str.maketrans('', '', string.punctuation))
    text = re.sub(' +', ' ', text)
    text = ''.join([i for i in text if i.isalpha() or i == ' '])
    return text

# %%
def convert_to_minutes(duration):
    total_minutes = 0
    if 'g' in duration:
        hours, rest = duration.split('g')
        total_minutes += int(hours) * 60
        duration = rest
    if 'min' in duration:
        minutes = duration.replace('min', '').strip()
        total_minutes += int(minutes)
    return total_minutes

# %%
df_laminacja['Description'] = df_laminacja['Description'].apply(preprocess_text)
df_laminacja['Duration'] = df_laminacja['Duration'].apply(convert_to_minutes)
df_laminacja.head(2)
# Out:
#                        Description  Duration  \
# 0  laminacja rzęs farbka anastasia        60
# 1       laminacja rzęs farbka liza        60
#
#                                     Location  Price  \
# 0  Aleje Jerozolimskie 107, 02-011, Warszawa  168.0
# 1  Aleje Jerozolimskie 107, 02-011, Warszawa  160.0
#
#                        geometry
# 0  POINT (20.9949283 52.225992)
# 1  POINT (20.9949283 52.225992)

# %%
df_hybrydy['Description'] = df_hybrydy['Description'].apply(preprocess_text)
df_hybrydy['Duration'] = df_hybrydy['Duration'].apply(convert_to_minutes)
df_hybrydy.head(2)
# Out:
#                       Description  Duration  \
# 0              manicure hybrydowy       120
# 1  manicure hybrydowy baby boomer       180
#
#                                             Location  Price  \
# 0  Generała Władysława Sikorskiego 14, 09-410, Płock  120.0
# 1  Generała Władysława Sikorskiego 14, 09-410, Płock  170.0
#
#                         geometry
# 0  POINT (19.7551731 52.5378894)
# 1  POINT (19.7551731 52.5378894)

# %% [markdown]
# ## Wczytanie geo danych

# %%
gdf_laminacja = gpd.GeoDataFrame(df_laminacja, geometry="geometry")
gdf_hybrydy = gpd.GeoDataFrame(df_hybrydy, geometry="geometry")
poland = gpd.read_file('powiaty-max.geojson')
poland_woj = gpd.read_file('wojewodztwa-max.geojson')
gdf_laminacja = gdf_laminacja.set_crs('epsg:4326')
gdf_hybrydy = gdf_hybrydy.set_crs('epsg:4326')

# %%
poland_woj.rename(columns = {'nazwa':'District'}, inplace = True) 
poland.rename(columns = {'nazwa':'District'}, inplace = True) 

result_gdf_laminacja_woj = gpd.sjoin(gdf_laminacja, poland_woj, how='left', predicate='within')
result_gdf_laminacja_pow = gpd.sjoin(gdf_laminacja, poland, how='left', predicate='within')

result_gdf_laminacja_woj.drop(columns=['id', 'index_right'], axis=1, inplace=True)
result_gdf_laminacja_pow.drop(columns=['id', 'index_right'], axis=1, inplace=True)

result_gdf_hybrydy_woj = gpd.sjoin(gdf_hybrydy, poland_woj, how='left', predicate='within')
result_gdf_hybrydy_pow = gpd.sjoin(gdf_hybrydy, poland, how='left', predicate='within')

result_gdf_hybrydy_woj.drop(columns=['id', 'index_right'], axis=1, inplace=True)
result_gdf_hybrydy_pow.drop(columns=['id', 'index_right'], axis=1, inplace=True)

# %%
result_gdf_hybrydy_woj.head(2)
# Out:
#                       Description  Duration  \
# 0              manicure hybrydowy       120
# 1  manicure hybrydowy baby boomer       180
#
#                                             Location  Price  \
# 0  Generała Władysława Sikorskiego 14, 09-410, Płock  120.0
# 1  Generała Władysława Sikorskiego 14, 09-410, Płock  170.0
#
#                     geometry     District
# 0  POINT (19.75517 52.53789)  mazowieckie
# 1  POINT (19.75517 52.53789)  mazowieckie

# %%
result_gdf_hybrydy_pow.head(2)
# Out:
#                       Description  Duration  \
# 0              manicure hybrydowy       120
# 1  manicure hybrydowy baby boomer       180
#
#                                             Location  Price  \
# 0  Generała Władysława Sikorskiego 14, 09-410, Płock  120.0
# 1  Generała Władysława Sikorskiego 14, 09-410, Płock  170.0
#
#                     geometry      District
# 0  POINT (19.75517 52.53789)  powiat Płock
# 1  POINT (19.75517 52.53789)  powiat Płock

# %%
def cv_function(df, col_name,max_features):
    # Initialize CountVectorizer
    cv_vectorizer = CountVectorizer(max_features=max_features)

    # Fit and transform the 'description' column
    cv_matrix = cv_vectorizer.fit_transform(df[col_name])

    # Convert the TF-IDF matrix to a DataFrame
    cv_df = pd.DataFrame(cv_matrix.toarray(), columns=cv_vectorizer.get_feature_names_out())

    df.reset_index(drop=True, inplace=True)
    cv_df.reset_index(drop=True, inplace=True)

    # Concatenate the original DataFrame with the TF-IDF DataFrame
    df=pd.concat([df, cv_df], axis=1)

    return df

# %%
def regression_base(df, dependent_col, independent_cols):
    model_base = spreg.OLS(
        #Dependent variable
        df[[dependent_col]].values,
        #Independent Variable
        df[independent_cols].values,
        #Dependent Variable name
        name_y=dependent_col,
        #Independent Variables names
        name_x=independent_cols,    
    )
    return model_base

# %%
def regression_regimes(df, dependent_col, independent_cols, neighborhood_col):
    model = spreg.OLS_Regimes(
        #Dependent variable
        df[[dependent_col]].values,
        #Independent Variables
        df[independent_cols].values,
        #Variable specifying neighborhood
        df[neighborhood_col].to_list(),
        #Allow constatnt term to vary by group/regime
        constant_regi="many",
        #Variables to be allowed to vary (True) or kept
        #constant (False). Here we set all to False
        cols2regi=[False]* len(independent_cols),
        #Allow separate sigma cpefficients to be estimated
        #by regime (False so a single sigma)
        regime_err_sep=False,
        #Dependent Variable name
        name_y=dependent_col,
        #Independent Variables names
        name_x=independent_cols,    
    )
    return model

# %% [markdown]
# # Laminacja

# %% [markdown]
# ## Powiaty

# %%
powiaty_laminacja = cv_function(result_gdf_laminacja_pow, 'Description', 3)
columns_to_exclude = ['Location', 'Price','District', 'geometry', 'Description']
variable_names = list(powiaty_laminacja.columns.difference(columns_to_exclude))

# %%
powiaty_laminacja.head(2)
# Out:
#                        Description  Duration  \
# 0  laminacja rzęs farbka anastasia        60
# 1       laminacja rzęs farbka liza        60
#
#                                     Location  Price  \
# 0  Aleje Jerozolimskie 107, 02-011, Warszawa  168.0
# 1  Aleje Jerozolimskie 107, 02-011, Warszawa  160.0
#
#                     geometry         District  brwi  laminacja  rzęs
# 0  POINT (20.99493 52.22599)  powiat Warszawa     0          1     1
# 1  POINT (20.99493 52.22599)  powiat Warszawa     0          1     1

# %%
lam_model_base_pow = regression_base(powiaty_laminacja,'Price',variable_names)
print(lam_model_base_pow.summary)
# Out:
# REGRESSION RESULTS
# ------------------
#
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES
# -----------------------------------------
# Data set            :     unknown
# Weights matrix      :        None
# Dependent Variable  :       Price                Number of Observations:        1323
# Mean dependent var  :    146.7015                Number of Variables   :           5
# S.D. dependent var  :     54.3118                Degrees of Freedom    :        1318
# R-squared           :      0.5767
# Adjusted R-squared  :      0.5754
# Sum squared residual: 1.65073e+06                F-statistic           :    448.8922
# Sigma-square        :    1252.454                Prob(F-statistic)     :  3.531e-244
# S.E. of regression  :      35.390                Log likelihood        :   -6593.138
# Sigma-square ML     :    1247.721                Akaike info criterion :   13196.276
# S.E of regression ML:     35.3231                Schwarz criterion     :   13222.215
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     t-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT        57.36793         7.88000         7.28019         0.00000
#             Duration         0.81259         0.03044        26.69410         0.00000
#                 brwi        57.29499         3.46386        16.54078         0.00000
#            laminacja        12.67884         4.67048         2.71467         0.00672
#                 rzęs         5.03395         5.83154         0.86323         0.38817
# ------------------------------------------------------------------------------------
#
# REGRESSION DIAGNOSTICS
# MULTICOLLINEARITY CONDITION NUMBER           19.942
#
# TEST ON NORMALITY OF ERRORS
# TEST                             DF        VALUE           PROB
# Jarque-Bera                       2        3326.275           0.0000
#
# DIAGNOSTICS FOR HETEROSKEDASTICITY
# RANDOM COEFFICIENTS
# TEST                             DF        VALUE           PROB
# Breusch-Pagan test                4        2809.118           0.0000
# Koenker-Bassett test              4         580.590           0.0000
# ================================ END OF REPORT =====================================

# %%
# Build full table of regression coefficients
base_pow_lam = pd.DataFrame(
    {
        # Pull out regression coefficients and
        # flatten as they are returned as Nx1 array
        "Coeff.": lam_model_base_pow.betas.flatten(),
        # Pull out and flatten standard errors
        "Std. Error": lam_model_base_pow.std_err.flatten(),
        # Pull out P-values from t-stat object
        "P-Value": [i[1] for i in lam_model_base_pow.t_stat],
    },
    index=lam_model_base_pow.name_x
    # Round to four decimals
).round(4)
base_pow_lam
# Out:
#             Coeff.  Std. Error  P-Value
# CONSTANT   57.3679      7.8800   0.0000
# Duration    0.8126      0.0304   0.0000
# brwi       57.2950      3.4639   0.0000
# laminacja  12.6788      4.6705   0.0067
# rzęs        5.0340      5.8315   0.3882

# %%
lam_model_regimes_pow = regression_regimes(powiaty_laminacja, 'Price', variable_names, 'District')
print(lam_model_regimes_pow.summary)
# Out:
# d:\2sem\pdp\.venv\lib\site-packages\spreg\diagnostics.py:607: ComplexWarning: Casting complex values to real discards the imaginary part
#   ci_result = sqrt(max_eigval / min_eigval)
# REGRESSION RESULTS
# ------------------
#
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES - REGIMES
# ---------------------------------------------------
# Data set            :     unknown
# Weights matrix      :        None
# Dependent Variable  :       Price                Number of Observations:
# powiat wałbrzyski_CONSTANT        68.44300        35.38517         1.93423         0.05333
# powiat wejherowski_CONSTANT        54.46739        14.44750         3.77002         0.00017
# powiat wielicki_CONSTANT        42.60279        15.80409         2.69568         0.00713
# powiat wieluński_CONSTANT        40.44300        35.38517         1.14294         0.25331
# powiat wieruszowski_CONSTANT        68.44300        35.38517         1.93423         0.05333
# powiat wołomiński_CONSTANT        42.96061        12.91730         3.32582         0.00091
# powiat wołowski_CONSTANT        47.11947        25.64940         1.83706         0.06646
# powiat wrocławski_CONSTANT        58.15651        13.94253         4.17116         0.00003
# powiat wrzesiński_CONSTANT        63.44300        25.63119         2.47523         0.01346
# powiat wąbrzeski_CONSTANT        48.44300        35.38517         1.36902         0.17127
# powiat zambrowski_CONSTANT        27.44300        35.38517         0.77555         0.43818
# powiat zawierciański_CONSTANT        60.89398        21.42857         2.84172         0.00457
# powiat zduńskowolski_CONSTANT        23.73711        35.34832         0.67152         0.50203
# powiat zgierski_CONSTANT        40.01163        35.40311         1.13017         0.25864
# powiat zgorzelecki_CONSTANT        61.58025        35.42388         1.73838         0.08242
# powiat zielonogórski_CONSTANT        78.44300        35.38517         2.21683         0.02683
# powiat Łódź_CONSTANT        51.77448        10.24423         5.05402         0.00000
# powiat łódzki wschodni_CONSTANT        69.17830        25.80432         2.68088         0.00745
# powiat łęczycki_CONSTANT        91.09006        35.36356         2.57582         0.01013
# powiat łęczyński_CONSTANT       -18.82937        26.06356        -0.72244         0.47017
# powiat Świnoujście_CONSTANT        52.62601        21.50363         2.44731         0.01454
# powiat Świętochłowice_CONSTANT        54.34496        21.44396         2.53428         0.01140
# powiat średzki_CONSTANT        30.89398        21.42857         1.44172         0.14966
# powiat śremski_CONSTANT        67.21214        25.59634         2.62585         0.00876
# powiat świdnicki_CONSTANT        53.71612        13.20401         4.06817         0.00005
# powiat Żory_CONSTANT        65.79594        35.41314         1.85795         0.06344
# powiat żarski_CONSTANT        38.46090        26.50997         1.45081         0.14711
# powiat żyrardowski_CONSTANT        88.44300        25.63119         3.45060         0.00058
# powiat żywiecki_CONSTANT        -1.70406        25.66979        -0.06638         0.94708
# ------------------------------------------------------------------------------------
# Regimes variable: unknown
#
# REGIMES DIAGNOSTICS - CHOW TEST
#                  VARIABLE        DF        VALUE           PROB
#                  CONSTANT        189         257.817           0.0006
#               Global test        189         257.817           0.0006
#
# REGRESSION DIAGNOSTICS
# MULTICOLLINEARITY CONDITION NUMBER           21.016
#
# TEST ON NORMALITY OF ERRORS
# TEST                             DF        VALUE           PROB
# Jarque-Bera                       2        5468.072           0.0000
#
# DIAGNOSTICS FOR HETEROSKEDASTICITY
# RANDOM COEFFICIENTS
# TEST                             DF        VALUE           PROB
# Breusch-Pagan test               193        4108.559           0.0000
# Koenker-Bassett test             193         689.162           0.0000
# ================================ END OF REPORT =====================================

# %%
# Build full table of regression coefficients
regimes_pow_lam = pd.DataFrame(
    {
        # Pull out regression coefficients and
        # flatten as they are returned as Nx1 array
        "Coeff.": lam_model_regimes_pow.betas.flatten(),
        # Pull out and flatten standard errors
        "Std. Error": lam_model_regimes_pow.std_err.flatten(),
        # Pull out P-values from t-stat object
        "P-Value": [i[1] for i in lam_model_regimes_pow.t_stat],
    },
    index=lam_model_regimes_pow.name_x
    # Round to four decimals
).round(4)
regimes_pow_lam
# Out:
#                                  Coeff.  Std. Error  P-Value
# powiat Biała Podlaska_CONSTANT  38.4430     35.3852   0.2775
# powiat Białystok_CONSTANT       46.3793     10.5593   0.0000
# powiat Bielsko-Biała_CONSTANT   45.9446     14.1023   0.0012
# powiat Bydgoszcz_CONSTANT       46.8965     11.5908   0.0001
# powiat Bytom_CONSTANT           51.8127     16.1731   0.0014
# ...                                 ...         ...      ...
# powiat żywiecki_CONSTANT        -1.7041     25.6698   0.9471
# _Global_Duration                 0.8431      0.0317   0.0000
# _Global_brwi                    55.0107      3.5226   0.0000
# _Global_laminacja               13.6516      4.6882   0.0037
# _Global_rzęs                     7.3171      5.9386   0.2182
#
# [194 rows x 3 columns]

# %%
#max features = 4
powiaty_laminacja = cv_function(result_gdf_laminacja_pow, 'Description', 4)
variable_names = list(powiaty_laminacja.columns.difference(columns_to_exclude))

lam_model_regimes_pow_4 = regression_regimes(powiaty_laminacja, 'Price', variable_names, 'District')
print(lam_model_regimes_pow_4.summary)
# Out:
# d:\2sem\pdp\.venv\lib\site-packages\spreg\diagnostics.py:607: ComplexWarning: Casting complex values to real discards the imaginary part
#   ci_result = sqrt(max_eigval / min_eigval)
# REGRESSION RESULTS
# ------------------
#
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES - REGIMES
# ---------------------------------------------------
# Data set            :     unknown
# Weights matrix      :        None
# Dependent Variable  :       Price                Number of Observations:        1323
# Mean dependent var  :    146.7015                Number of Variables   :         195
# S.D. dependent var  :     54.3118                Degrees of Freedom    :        1128
# R-squared           :      0.6567
# Adjusted R-squared  :      0.5977
# Sum squared residual:  1.3386e+06                F-statistic           :     11.1242
# Sigma-square        :    1186.701                Prob(F-statistic)     :  1.343e-162
# S.E. of regression  :      34.449                Log likelihood        :   -6454.489
# Sigma-square ML     :    1011.790                Akaike info criterion :   13298.979
# S.E of regression ML:     31.8086                Schwarz criterion     :   14310.572
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     t-Statistic     Probability
# ------------------------------------------------------------------------------------
#     _Global_Duration         0.84089         0.03164        26.57863         0.00000
#         _Global_brwi        55.31184         3.52017        15.71281         0.00000
#       _Global_farbka        -8.23118         3.91101        -2.10462         0.03555
#    _Global_laminacja        13.39564         4.68266         2.86069         0.00431
#         _Global_rzęs         7.40966         5.92975         1.24957         0.21171
# powiat Biała Podlaska_CONSTANT        38.74101        35.33184         1.09649         0.27310
# powiat Białystok_CONSTANT        47.34762        10.55332         4.48652         0.00001
# powiat Bielsko-Biała_CONSTANT        47.18578        14.09331         3.34810         0.00084
# powiat Bydgoszcz_CONSTANT        47.20304        11.57420         4.07830         0.00005
# powiat Bytom_CONSTANT        52.03832        16.14890         3.22241         0.00131
# powiat Chorzów_CONSTANT        43.24483        25.57449         1.69094         0.09113
# powiat Częstochowa_CONSTANT        34.00619        16.11270         2.11052         0.03503
# powiat Dąbrowa Górnicza_CONSTANT        54.87132        21.47776         2.55480         0.01076
# powiat Gdańsk_CONSTANT        44.82059        10.02529         4.47075         0.00001
# powiat Gdynia_CONSTANT        34.72725        12.43168         2.79345         0.00530
# powiat Gliwice_CONSTANT        48.02918        12.66651         3.79182         0.00016
# powiat Gorzów Wielkopolski_CONSTANT        43.51417        35.39417         1.22942         0.21917
# powiat Grudziądz_CONSTANT        43.51417        35.39417         1.22942         0.21917
# powiat Jastrzębie-Zdrój_CONSTANT        23.51417        35.39417         0.66435         0.50660
# powiat Jaworzno_CONSTANT        54.78095        18.96721         2.88819         0.00395
# powiat Jelenia Góra_CONSTANT        48.24101        25.59274         1.88495         0.05969
# powiat Kalisz_CONSTANT        -9.66793        35.34979        -0.27349         0.78452
# powiat Katowice_CONSTANT        55.52052        10.13069         5.48043         0.00000
# powiat Kielce_CONSTANT        60.50792        10.87771         5.56256         0.00000
# powiat Konin_CONSTANT        38.74101        35.33184         1.09649         0.27310
# powiat Koszalin_CONSTANT        34.09325        21.37217         1.59522         0.11094
# powiat Kraków_CONSTANT        52.15761         8.87569         5.87646         0.00000
std_err.flatten(),
        # Pull out P-values from t-stat object
        "P-Value": [i[1] for i in lam_model_regimes_pow_4.t_stat],
    },
    index=lam_model_regimes_pow_4.name_x
    # Round to four decimals
).round(4)
regimes_pow_4_lam
# Out:
#                                  Coeff.  Std. Error  P-Value
# powiat Biała Podlaska_CONSTANT  38.7410     35.3318   0.2731
# powiat Białystok_CONSTANT       47.3476     10.5533   0.0000
# powiat Bielsko-Biała_CONSTANT   47.1858     14.0933   0.0008
# powiat Bydgoszcz_CONSTANT       47.2030     11.5742   0.0000
# powiat Bytom_CONSTANT           52.0383     16.1489   0.0013
# ...                                 ...         ...      ...
# _Global_Duration                 0.8409      0.0316   0.0000
# _Global_brwi                    55.3118      3.5202   0.0000
# _Global_farbka                  -8.2312      3.9110   0.0355
# _Global_laminacja               13.3956      4.6827   0.0043
# _Global_rzęs                     7.4097      5.9298   0.2117
#
# [195 rows x 3 columns]

# %% [markdown]
# ## Województwa

# %%
wojewodztwa_laminacja = cv_function(result_gdf_laminacja_woj, 'Description', 5)
columns_to_exclude = ['Location', 'Price','District', 'geometry', 'Description']
variable_names = list(wojewodztwa_laminacja.columns.difference(columns_to_exclude))

# %%
wojewodztwa_laminacja.head(2)
# Out:
#                        Description  Duration  \
# 0  laminacja rzęs farbka anastasia        60
# 1       laminacja rzęs farbka liza        60
#
#                                     Location  Price  \
# 0  Aleje Jerozolimskie 107, 02-011, Warszawa  168.0
# 1  Aleje Jerozolimskie 107, 02-011, Warszawa  160.0
#
#                     geometry     District  brwi  farbka  henna  laminacja  \
# 0  POINT (20.99493 52.22599)  mazowieckie     0       1      0          1
# 1  POINT (20.99493 52.22599)  mazowieckie     0       1      0          1
#
#    rzęs
# 0     1
# 1     1

# %%
lam_model_base_woj = regression_base(wojewodztwa_laminacja,'Price',variable_names)
print(lam_model_base_woj.summary)
# Out:
# REGRESSION RESULTS
# ------------------
#
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES
# -----------------------------------------
# Data set            :     unknown
# Weights matrix      :        None
# Dependent Variable  :       Price                Number of Observations:        1323
# Mean dependent var  :    146.7015                Number of Variables   :           7
# S.D. dependent var  :     54.3118                Degrees of Freedom    :        1316
# R-squared           :      0.5831
# Adjusted R-squared  :      0.5812
# Sum squared residual: 1.62568e+06                F-statistic           :    306.7926
# Sigma-square        :    1235.320                Prob(F-statistic)     :  6.913e-246
# S.E. of regression  :      35.147                Log likelihood        :   -6583.021
# Sigma-square ML     :    1228.784                Akaike info criterion :   13180.042
# S.E of regression ML:     35.0540                Schwarz criterion     :   13216.356
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     t-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT        57.75982         7.83746         7.36971         0.00000
#             Duration         0.80407         0.03029        26.54494         0.00000
#                 brwi        55.02410         3.49772        15.73143         0.00000
#               farbka        -6.90217         3.72900        -1.85094         0.06440
#                henna        16.26929         3.99860         4.06875         0.00005
#            laminacja        15.03227         4.68286         3.21006         0.00136
#                 rzęs         2.59801         5.82365         0.44611         0.65559
# ------------------------------------------------------------------------------------
#
# REGRESSION DIAGNOSTICS
# MULTICOLLINEARITY CONDITION NUMBER           20.403
#
# TEST ON NORMALITY OF ERRORS
# TEST                             DF        VALUE           PROB
# Jarque-Bera                       2        3618.294           0.0000
#
# DIAGNOSTICS FOR HETEROSKEDASTICITY
# RANDOM COEFFICIENTS
# TEST                             DF        VALUE           PROB
# Breusch-Pagan test                6        2971.286           0.0000
# Koenker-Bassett test              6         593.886           0.0000
# ================================ END OF REPORT =====================================

# %%
# Build full table of regression coefficients
base_woj_lam = pd.DataFrame(
    {
        # Pull out regression coefficients and
        # flatten as they are returned as Nx1 array
        "Coeff.": lam_model_base_woj.betas.flatten(),
        # Pull out and flatten standard errors
        "Std. Error": lam_model_base_woj.std_err.flatten(),
        # Pull out P-values from t-stat object
        "P-Value": [i[1] for i in lam_model_base_woj.t_stat],
    },
    index=lam_model_base_woj.name_x
    # Round to four decimals
).round(4)
base_woj_lam
# Out:
#             Coeff.  Std. Error  P-Value
# CONSTANT   57.7598      7.8375   0.0000
# Duration    0.8041      0.0303   0.0000
# brwi       55.0241      3.4977   0.0000
# farbka     -6.9022      3.7290   0.0644
# henna      16.2693      3.9986   0.0001
# laminacja  15.0323      4.6829   0.0014
# rzęs        2.5980      5.8237   0.6556

# %%
lam_model_regimes_woj = regression_regimes(wojewodztwa_laminacja, 'Price', variable_names, 'District')
print(lam_model_regimes_woj.summary)
# Out:
# REGRESSION RESULTS
# ------------------
#
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES - REGIMES
# ---------------------------------------------------
# Data set            :     unknown
# Weights matrix      :        None
# Dependent Variable  :       Price                Number of Observations:        1323
# Mean dependent var  :    146.7015                Number of Variables   :          22
# S.D. dependent var  :     54.3118                Degrees of Freedom    :        1301
# R-squared           :      0.6174
# Adjusted R-squared  :      0.6112
# Sum squared residual: 1.49204e+06                F-statistic           :     99.9668
# Sigma-square        :    1146.840                Prob(F-statistic)     :  2.014e-253
# S.E. of regression  :      33.865                Log likelihood        :   -6526.276
# Sigma-square ML     :    1127.769                Akaike info criterion :   13096.551
# S.E of regression ML:     33.5823                Schwarz criterion     :   13210.680
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     t-Statistic     Probability
# ------------------------------------------------------------------------------------
#     _Global_Duration         0.82622         0.02948        28.02387         0.00000
#         _Global_brwi        52.87013         3.39812        15.55863         0.00000
#       _Global_farbka        -7.56816         3.60469        -2.09953         0.03596
#        _Global_henna        14.53629         3.87338         3.75287         0.00018
#    _Global_laminacja        15.12244         4.53914         3.33156         0.00089
#         _Global_rzęs         3.29526         5.63108         0.58519         0.55852
# dolnośląskie_CONSTANT        44.99675         7.97933         5.63916         0.00000
# kujawsko-pomorskie_CONSTANT        42.18041         9.25080         4.55965         0.00001
#   lubelskie_CONSTANT        49.86627        10.24971         4.86514         0.00000
#    lubuskie_CONSTANT        63.18782        10.65620         5.92968         0.00000
# mazowieckie_CONSTANT        70.50217         7.70478         9.15044         0.00000
# małopolskie_CONSTANT        53.56720         8.21508         6.52059         0.00000
#    opolskie_CONSTANT        49.14663         9.74562         5.04294         0.00000
# podkarpackie_CONSTANT        54.46630        10.35572         5.25954         0.00000
#   podlaskie_CONSTANT        51.79286         9.83538         5.26597         0.00000
#   pomorskie_CONSTANT        46.63780         8.47756         5.50132         0.00000
# warmińsko-mazurskie_CONSTANT        49.14408        10.73940         4.57606         0.00001
# wielkopolskie_CONSTANT        55.42973         8.09996         6.84321         0.00000
# zachodniopomorskie_CONSTANT        37.10945         9.59062         3.86935         0.00011
#     łódzkie_CONSTANT        54.52241         8.75516         6.22746         0.00000
#     śląskie_CONSTANT        50.68286         7.98671         6.34590         0.00000
# świętokrzyskie_CONSTANT        62.40725         9.77197         6.38635         0.00000
# ------------------------------------------------------------------------------------
# Regimes variable: unknown
#
# REGIMES DIAGNOSTICS - CHOW TEST
#                  VARIABLE        DF        VALUE           PROB
#                  CONSTANT        15         116.531           0.0000
#               Global test        15         116.531           0.0000
#
# REGRESSION DIAGNOSTICS
# MULTICOLLINEARITY CONDITION NUMBER           20.514
#
# TEST ON NORMALITY OF ERRORS
# TEST                             DF        VALUE           PROB
# Jarque-Bera                       2        3828.251           0.0000
#
# DIAGNOSTICS FOR HETEROSKEDASTICITY
# RANDOM COEFFICIENTS
# TEST                             DF        VALUE           PROB
# Breusch-Pagan test               21        3271.882           0.0000
# Koenker-Bassett test             21         636.019           0.0000
# ================================ END OF REPORT =====================================

# %%
# Build full table of regression coefficients
regimes_woj_lam = pd.DataFrame(
    {
        # Pull out regression coefficients and
        # flatten as they are returned as Nx1 array
        "Coeff.": lam_model_regimes_woj.betas.flatten(),
        # Pull out and flatten standard errors
        "Std. Error": lam_model_regimes_woj.std_err.flatten(),
        # Pull out P-values from t-stat object
        "P-Value": [i[1] for i in lam_model_regimes_woj.t_stat],
    },
    index=lam_model_regimes_woj.name_x
    # Round to four decimals
).round(4)
regimes_woj_lam
# Out:
#                                Coeff.  Std. Error  P-Value
# dolnośląskie_CONSTANT         44.9967      7.9793   0.0000
# kujawsko-pomorskie_CONSTANT   42.1804      9.2508   0.0000
# lubelskie_CONSTANT            49.8663     10.2497   0.0000
# lubuskie_CONSTANT             63.1878     10.6562   0.0000
# mazowieckie_CONSTANT          70.5022      7.7048   0.0000
# małopolskie_CONSTANT          53.5672      8.2151   0.0000
# opolskie_CONSTANT             49.1466      9.7456   0.0000
# podkarpackie_CONSTANT         54.4663     10.3557   0.0000
# podlaskie_CONSTANT            51.7929      9.8354   0.0000
# pomorskie_CONSTANT            46.6378      8.4776   0.0000
# warmińsko-mazurskie_CONSTANT  49.1441     10.7394   0.0000
# wielkopolskie_CONSTANT        55.4297      8.1000   0.0000
# zachodniopomorskie_CONSTANT   37.1094      9.5906   0.0001
# łódzkie_CONSTANT              54.5224      8.7552   0.0000
# śląskie_CONSTANT              50.6829      7.9867   0.0000
# świętokrzyskie_CONSTANT       62.4073      9.7720   0.0000
# _Global_Duration               0.8262      0.0295   0.0000
# _Global_brwi                  52.8701      3.3981   0.0000
# _Global_farbka                -7.5682      3.6047   0.0360
# _Global_henna                 14.5363      3.8734   0.0002
# _Global_laminacja             15.1224      4.5391   0.0009
# _Global_rzęs                   3.2953      5.6311   0.5585

# %%
#max features = 7
wojewodztwa_laminacja = cv_function(result_gdf_laminacja_woj, 'Description', 7)
variable_names = list(wojewodztwa_laminacja.columns.difference(columns_to_exclude))

lam_model_regimes_woj_7 = regression_regimes(wojewodztwa_laminacja, 'Price', variable_names, 'District')
print(lam_model_regimes_woj_7.summary)
# Out:
# REGRESSION RESULTS
# ------------------
#
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES - REGIMES
# ---------------------------------------------------
# Data set            :     unknown
# Weights matrix      :        None
# Dependent Variable  :       Price                Number of Observations:        1323
# Mean dependent var  :    146.7015                Number of Variables   :          24
# S.D. dependent var  :     54.3118                Degrees of Freedom    :        1299
# R-squared           :      0.6184
# Adjusted R-squared  :      0.6117
# Sum squared residual: 1.48797e+06                F-statistic           :     91.5373
# Sigma-square        :    1145.474                Prob(F-statistic)     :  3.482e-252
# S.E. of regression  :      33.845                Log likelihood        :   -6524.469
# Sigma-square ML     :    1124.694                Akaike info criterion :   13096.939
# S.E of regression ML:     33.5365                Schwarz criterion     :   13221.443
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     t-Statistic     Probability
# ------------------------------------------------------------------------------------
#     _Global_Duration         0.82485         0.02948        27.98185         0.00000
#         _Global_brwi        52.89155         3.39807        15.56516         0.00000
#       _Global_farbka        -8.24913         3.62202        -2.27749         0.02292
#   _Global_farbowanie        -4.37437         4.12222        -1.06117         0.28881
#        _Global_henna        13.82608         3.89187         3.55255         0.00040
#  _Global_koloryzacja        -7.08285         4.38133        -1.61660         0.10621
#    _Global_laminacja        15.11130         4.55552         3.31714         0.00093
#         _Global_rzęs         3.82882         5.63562         0.67940         0.49701
# dolnośląskie_CONSTANT        45.21584         7.98551         5.66223         0.00000
# kujawsko-pomorskie_CONSTANT        42.14457         9.25458         4.55392         0.00001
#   lubelskie_CONSTANT        50.44432        10.27019         4.91172         0.00000
#    lubuskie_CONSTANT        62.89759        10.65586         5.90263         0.00000
# mazowieckie_CONSTANT        70.90344         7.72762         9.17533         0.00000
# małopolskie_CONSTANT        54.23507         8.22088         6.59723         0.00000
#    opolskie_CONSTANT        49.34822         9.74369         5.06463         0.00000
# podkarpackie_CONSTANT        54.96992        10.35303         5.30955         0.00000
#   podlaskie_CONSTANT        51.86972         9.83541         5.27377         0.00000
#   pomorskie_CONSTANT        46.69655         8.48014         5.50658         0.00000
# warmińsko-mazurskie_CONSTANT        49.67307        10.73667         4.62649         0.00000
# wielkopolskie_CONSTANT        55.71250         8.10148         6.87683         0.00000
# zachodniopomorskie_CONSTANT        37.04784         9.59909         3.85952         0.00012
#     łódzkie_CONSTANT        54.92657         8.75609         6.27296         0.00000
#     śląskie_CONSTANT        50.56655         7.98655         6.33146         0.00000
# świętokrzyskie_CONSTANT        62.45394         9.77184         6.39121         0.00000
# ------------------------------------------------------------------------------------
# Regimes variable: unknown
#
# REGIMES DIAGNOSTICS - CHOW TEST
#                  VARIABLE        DF        VALUE           PROB
#                  CONSTANT        15         117.402           0.0000
#               Global test        15         117.402           0.0000
#
# REGRESSION DIAGNOSTICS
# MULTICOLLINEARITY CONDITION NUMBER           20.805
#
# TEST ON NORMALITY OF ERRORS
# TEST                             DF        VALUE           PROB
# Jarque-Bera                       2        3852.122           0.0000
#
# DIAGNOSTICS FOR HETEROSKEDASTICITY
# RANDOM COEFFICIENTS
# TEST                             DF        VALUE           PROB
# Breusch-Pagan test               23        3290.978           0.0000
# Koenker-Bassett test             23         638.199           0.0000
# ================================ END OF REPORT =====================================

# %%
# Build full table of regression coefficients
regimes_woj_7_lam = pd.DataFrame(
    {
        # Pull out regression coefficients and
        # flatten as they are returned as Nx1 array
        "Coeff.": lam_model_regimes_woj_7.betas.flatten(),
        # Pull out and flatten standard errors
        "Std. Error": lam_model_regimes_woj_7.std_err.flatten(),
        # Pull out P-values from t-stat object
        "P-Value": [i[1] for i in lam_model_regimes_woj_7.t_stat],
    },
    index=lam_model_regimes_woj_7.name_x
    # Round to four decimals
).round(4)
regimes_woj_7_lam
# Out:
#                                Coeff.  Std. Error  P-Value
# dolnośląskie_CONSTANT         45.2158      7.9855   0.0000
# kujawsko-pomorskie_CONSTANT   42.1446      9.2546   0.0000
# lubelskie_CONSTANT            50.4443     10.2702   0.0000
# lubuskie_CONSTANT             62.8976     10.6559   0.0000
# mazowieckie_CONSTANT          70.9034      7.7276   0.0000
# małopolskie_CONSTANT          54.2351      8.2209   0.0000
# opolskie_CONSTANT             49.3482      9.7437   0.0000
# podkarpackie_CONSTANT         54.9699     10.3530   0.0000
# podlaskie_CONSTANT            51.8697      9.8354   0.0000
# pomorskie_CONSTANT            46.6966      8.4801   0.0000
# warmińsko-mazurskie_CONSTANT  49.6731     10.7367   0.0000
# wielkopolskie_CONSTANT        55.7125      8.1015   0.0000
# zachodniopomorskie_CONSTANT   37.0478      9.5991   0.0001
# łódzkie_CONSTANT              54.9266      8.7561   0.0000
# śląskie_CONSTANT              50.5665      7.9866   0.0000
# świętokrzyskie_CONSTANT       62.4539      9.7718   0.0000
# _Global_Duration               0.8248      0.0295   0.0000
# _Global_brwi                  52.8915      3.3981   0.0000
# _Global_farbka                -8.2491      3.6220   0.0229
# _Global_farbowanie            -4.3744      4.1222   0.2888
# _Global_henna                 13.8261      3.8919   0.0004
# _Global_koloryzacja           -7.0829      4.3813   0.1062
# _Global_laminacja             15.1113      4.5555   0.0009
# _Global_rzęs                   3.8288      5.6356   0.4970

# %% [markdown]
# # Hybrydy

# %% [markdown]
# ## Powiaty

# %%
powiaty_hybrydy = cv_function(result_gdf_hybrydy_pow, 'Description', 5)
columns_to_exclude = ['Location', 'Price','District', 'geometry', 'Description']
variable_names = list(powiaty_hybrydy.columns.difference(columns_to_exclude))

# %%
powiaty_hybrydy.head(2)
# Out:
#                       Description  Duration  \
# 0              manicure hybrydowy       120
# 1  manicure hybrydowy baby boomer       180
#
#                                             Location  Price  \
# 0  Generała Władysława Sikorskiego 14, 09-410, Płock  120.0
# 1  Generała Władysława Sikorskiego 14, 09-410, Płock  170.0
#
#                     geometry      District  french  hybrydowy  kolor  \
# 0  POINT (19.75517 52.53789)  powiat Płock       0          1      0
# 1  POINT (19.75517 52.53789)  powiat Płock       0          1      0
#
#    manicure  ze
# 0         1   0
# 1         1   0

# %%
hyb_model_base_pow = regression_base(powiaty_hybrydy,'Price',variable_names)
print(hyb_model_base_pow.summary)
# Out:
# REGRESSION RESULTS
# ------------------
#
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES
# -----------------------------------------
# Data set            :     unknown
# Weights matrix      :        None
# Dependent Variable  :       Price                Number of Observations:        4536
# Mean dependent var  :    116.7315                Number of Variables   :           7
# S.D. dependent var  :     31.2829                Degrees of Freedom    :        4529
# R-squared           :      0.2353
# Adjusted R-squared  :      0.2342
# Sum squared residual: 3.39398e+06                F-statistic           :    232.2043
# Sigma-square        :     749.388                Prob(F-statistic)     :  2.392e-259
# S.E. of regression  :      27.375                Log likelihood        :  -21445.276
# Sigma-square ML     :     748.231                Akaike info criterion :   42904.553
# S.E of regression ML:     27.3538                Schwarz criterion     :   42949.491
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     t-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT        25.92433         7.98489         3.24668         0.00118
#             Duration         0.45094         0.01516        29.74900         0.00000
#               french        12.43307         1.45447         8.54818         0.00000
#            hybrydowy        53.12451         3.52250        15.08147         0.00000
#                kolor        -0.32031         1.55001        -0.20665         0.83629
#             manicure        -3.63976         7.33985        -0.49589         0.62000
#                   ze         3.43604         1.95251         1.75981         0.07851
# ------------------------------------------------------------------------------------
#
# REGRESSION DIAGNOSTICS
# MULTICOLLINEARITY CONDITION NUMBER           53.250
#
# TEST ON NORMALITY OF ERRORS
# TEST                             DF        VALUE           PROB
# Jarque-Bera                       2     1092631.055           0.0000
#
# DIAGNOSTICS FOR HETEROSKEDASTICITY
# RANDOM COEFFICIENTS
# TEST                             DF        VALUE           PROB
# Breusch-Pagan test                6       65395.946           0.0000
# Koenker-Bassett test              6        1680.901           0.0000
# ================================ END OF REPORT =====================================

# %%
# Build full table of regression coefficients
base_pow_hyb = pd.DataFrame(
    {
        # Pull out regression coefficients and
        # flatten as they are returned as Nx1 array
        "Coeff.": hyb_model_base_pow.betas.flatten(),
        # Pull out and flatten standard errors
        "Std. Error": hyb_model_base_pow.std_err.flatten(),
        # Pull out P-values from t-stat object
        "P-Value": [i[1] for i in hyb_model_base_pow.t_stat],
    },
    index=hyb_model_base_pow.name_x
    # Round to four decimals
).round(4)
base_pow_hyb
# Out:
#             Coeff.  Std. Error  P-Value
# CONSTANT   25.9243      7.9849   0.0012
# Duration    0.4509      0.0152   0.0000
# french     12.4331      1.4545   0.0000
# hybrydowy  53.1245      3.5225   0.0000
# kolor      -0.3203      1.5500   0.8363
# manicure   -3.6398      7.3398   0.6200
# ze          3.4360      1.9525   0.0785

# %%
hyb_model_regimes_pow = regression_regimes(powiaty_hybrydy, 'Price', variable_names, 'District')
print(hyb_model_regimes_pow.summary)
# Out:
# d:\2sem\pdp\.venv\lib\site-packages\spreg\diagnostics.py:607: ComplexWarning: Casting complex values to real discards the imaginary part
#   ci_result = sqrt(max_eigval / min_eigval)
# REGRESSION RESULTS
# ------------------
#
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES - REGIMES
# ---------------------------------------------------
# Data set            :     unknown
# Weights matrix      :        None
# Dependent Variable  :       Price                Number of Observations:        4536
# Mean dependent var  :    116.7315                Number of Variables   :         285
# S.D. dependent var  :     31.2829                Degrees of Freedom    :        4251
# R-squared           :      0.3754
# Adjusted R-squared  :      0.3337
# Sum squared residual: 2.77194e+06                F-statistic           :      8.9969
# Sigma-square        :     652.067                Prob(F-statistic)     :  3.038e-267
# S.E. of regression  :      25.536                Log likelihood        :  -20986.106
# Sigma-square ML     :     611.097                Akaike info criterion :   42542.213
# S.E of regression ML:     24.7204                Schwarz criterion     :   44371.856
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     t-Statistic     Probability
# ------------------------------------------------------------------------------------
#     _Global_Duration         0.40576         0.01486        27.30521         0.00000
#       _Global_french        12.55900         1.39166         9.02446         0.00000
#    _Global_hybrydowy        53.92961         3.39651        15.87795         0.00000
#        _Global_kolor         1.53925         1.51172         1.01821         0.30864
#     _Global_manicure        -2.28812         6.96593        -0.32847         0.74257
#           _Global_ze         2.34473         1.86635         1.25632         0.20907
# powiat Biała Podlaska_CONSTANT        12.34045        19.58022         0.63025         0.52856
# powiat Białystok_CONSTANT        18.13158         9.00680         2.01310         0.04417
# powiat Bielsko-Biała_CONSTANT        21.64662         8.33091         2.59835         0.00940
# powiat Bydgoszcz_CONSTANT        21.75931         8.00942         2.71672         0.00662
# powiat Bytom_CONSTANT        35.74149         9.66298         3.69881         0.00022
# powiat Chełm_CONSTANT        17.10877        26.69688         0.64085         0.52165
# powiat Chorzów_CONSTANT        21.28840         9.91342         2.14743         0.03182
# powiat Suwałki_CONSTANT        50.42281        15.01643         3.35784         0.00079
# powiat Szczecin_CONSTANT        26.40403         8.12185         3.25099         0.00116
# powiat Słupsk_CONSTANT        30.99318         8.94773         3.46380         0.00054
# powiat Tarnobrzeg_CONSTANT        40.35484        14.84268         2.71884         0.00658
# powiat Tarnów_CONSTANT        23.67874         9.72314         2.43530         0.01492
# powiat Toruń_CONSTANT        31.55996         8.19201         3.85253         0.00012
# powiat Tychy_CONSTANT        25.82604         8.45753         3.05362         0.00228
# powiat Warszawa_CONSTANT        41.97344         7.68231         5.46365         0.00000
# powiat Wałbrzych_CONSTANT         8.95843        10.63930         0.84201         0.39983
# powiat Wrocław_CONSTANT        33.20307         8.11919         4.08946         0.00004
# powiat Włocławek_CONSTANT        11.84045        19.58022         0.60471         0.54540
# powiat Zabrze_CONSTANT        17.66267        10.36528         1.70402         0.08845
# powiat Zamość_CONSTANT        21.17176        12.87680         1.64418         0.10021
# powiat Zielona Góra_CONSTANT        20.98971         8.36799         2.50833         0.01217
# powiat aleksandrowski_CONSTANT        15.76546        14.84414         1.06207         0.28827
# powiat augustowski_CONSTANT        17.92680        26.62856         0.67322         0.50085
# powiat bełchatowski_CONSTANT        29.57531        11.39280         2.59597         0.00947
# powiat białostocki_CONSTANT        39.81167        19.58367         2.03290         0.04212
# powiat bielski_CONSTANT        28.14088        10.79836         2.60603         0.00919
# powiat bocheński_CONSTANT         9.01769        10.03889         0.89828         0.36909
# powiat bolesławiecki_CONSTANT        22.38362        14.83869         1.50846         0.13151
# powiat brodnicki_CONSTANT        33.88880        10.40041         3.25841         0.00113
# powiat brzeski_CONSTANT        12.45331        10.38085         1.19964         0.23035
# powiat brzeziński_CONSTANT        40.75411        19.59141         2.08020         0.03757
# powiat brzozowski_CONSTANT         5.75411        26.64314         0.21597         0.82902
# powiat buski_CONSTANT        59.23135        16.56715         3.57523         0.00035
# powiat bydgoski_CONSTANT        19.44078        11.38488         1.70760         0.08778
# powiat będziński_CONSTANT        17.39562        10.55759         1.64769         0.09949
# powiat chełmiński_CONSTANT        24.34045        14.84481         1.63966         0.10115
# powiat chojnicki_CONSTANT        -1.07320        19.57158        -0.05483         0.95627
# powiat choszczeński_CONSTANT        17.92680        26.62856         0.67322         0.50085
# powiat chrzanowski_CONSTANT        11.95375         9.40330         1.27123         0.20372
# powiat ciechanowski_CONSTANT         0.97786        11.41120         0.08569         0.93171
# powiat cieszyński_CONSTANT        10.04730        10.05092         0.99964         0.31754
# powiat czarnkowsko-trzcianecki_CONSTANT         1.84045        26.63492         0.06910         0.94491
# powiat częstochowski_CONSTANT        18.33038        16.58420         1.10529         0.26910
# powiat człuchowski_CONSTANT        12.70953        13.69256         0.92821         0.35335
# powiat działdowski_CONSTANT         9.81167        26.63745         0.36834         0.71264
# powiat dzierżoniowski_CONSTANT         2.85484        11.78120         0.24232         0.80854
# powiat dąbrowski_CONSTANT        19.90761        16.56609         1.20171         0.22954
# powiat dębicki_CONSTANT        35.42575        10.17869         3.48038         0.00051
# powiat ełcki_CONSTANT        27.19089        14.86298         1.82944         0.06740
# powiat legnicki_CONSTANT         2.92680        19.57158         0.14954         0.88113
# powiat leszczyński_CONSTANT       -16.80198        14.83803        -1.13236         0.25755
# powiat leżajski_CONSTANT       -22.07320        26.62856        -0.82893         0.40719
# powiat limanowski_CONSTANT         2.17379        16.57430         0.13115         0.89566
# powiat lubartowski_CONSTANT        14.90761        12.87468         1.15790         0.24697
# powiat lubański_CONSTANT        22.14754        16.57085         1.33654         0.18145
# powiat lubelski_CONSTANT        34.32703        13.73517         2.49921         0.01248
# powiat lubiński_CONSTANT        23.55244         9.49593         2.48027         0.01317
# powiat lubliniecki_CONSTANT         6.59346        16.56408         0.39806         0.69061
# powiat lwówecki_CONSTANT        18.94119        19.57038         0.96785         0.33317
# powiat lęborski_CONSTANT        10.58627        13.72273         0.77144         0.44049
# powiat makowski_CONSTANT        -8.15955        26.63492        -0.30635         0.75935
# powiat malborski_CONSTANT        21.42076        11.78305         1.81793         0.06915
# powiat miechowski_CONSTANT         5.98436        19.56722         0.30584         0.75974
# powiat mielecki_CONSTANT        16.16488        10.99927         1.46963         0.14174
# powiat mikołowski_CONSTANT         3.86923        19.57706         0.19764         0.84334
# powiat milicki_CONSTANT        15.89802        14.83683         1.07152         0.28399
# powiat międzychodzki_CONSTANT        14.01314        26.62407         0.52633         0.59868
# powiat międzyrzecki_CONSTANT         6.84045        26.63492         0.25682         0.79733
# powiat miński_CONSTANT        27.48189         9.27279         2.96371         0.00306
# powiat mogileński_CONSTANT        39.88761        14.70235         2.71301         0.00669
# powiat mrągowski_CONSTANT        15.89802        26.63047         0.59699         0.55055
# powiat myszkowski_CONSTANT       -13.30345        19.60026        -0.67874         0.49734
# powiat myślenicki_CONSTANT        20.87674        10.82376         1.92879         0.05382
# powiat mławski_CONSTANT        27.70209        16.57959         1.67085         0.09482
# powiat nakielski_CONSTANT        20.06290        13.71403         1.46295         0.14356
# powiat nowodworski_CONSTANT        17.51017         9.90440         1.76792         0.07715
# powiat nowomiejski_CONSTANT         6.16241        19.57284         0.31484         0.75290
# powiat nowosolski_CONSTANT        18.50712        16.57430         1.11662         0.26422
# powiat nowosądecki_CONSTANT         0.35484        14.84268         0.02391         0.98093
# powiat nowotarski_CONSTANT        19.14272        11.38750         1.68103         0.09283
# powiat nowotomyski_CONSTANT         9.77127        12.88635         0.75827         0.44833
# powiat nyski_CONSTANT        26.87146        11.79791         2.27765         0.02280
# powiat obornicki_CONSTANT        19.57860        13.68470         1.43069         0.15259
# powiat olecki_CONSTANT        -2.07320        19.57158        -0.10593         0.91564
# powiat oleski_CONSTANT        41.84045        26.63492         1.57089         0.11628
# powiat oleśnicki_CONSTANT        24.28574        11.38601         2.13295         0.03299
# powiat olkuski_CONSTANT        18.59017        13.70126         1.35682         0.17491
# powiat olsztyński_CONSTANT        22.82470        13.69677         1.66643         0.09570
# powiat opolski_CONSTANT        55.89353        12.28480         4.54981         0.00001
# powiat ostrowiecki_CONSTANT        14.60383        10.55930         1.38303         0.16673
# powiat ostrowski_CONSTANT        14.83348         8.85104         1.67590         0.09383
# powiat ostrzeszowski_CONSTANT        12.51778        19.60353         0.63855         0.52315
# powiat ostródzki_CONSTANT        25.17379        12.88524         1.95369         0.05080
# powiat otwocki_CONSTANT        17.21079         9.76502         1.76249         0.07806
# powiat oławski_CONSTANT        45.46153        11.07836         4.10363         0.00004
# powiat oświęcimski_CONSTANT        26.16960         9.88896         2.64634         0.00817
# powiat pabianicki_CONSTANT        25.17729        10.20716         2.46663         0.01368
# powiat pajęczański_CONSTANT        12.92680        26.62856         0.48545         0.62738
# powiat piaseczyński_CONSTANT        34.47380         8.34207         4.13252         0.00004
# powiat pilski_CONSTANT        23.25495        12.26159         1.89657         0.05795
# powiat piotrkowski_CONSTANT         9.95558        26.62685         0.37389         0.70850
# powiat piski_CONSTANT        36.92038        19.40210         1.90291         0.05712
# powiat pleszewski_CONSTANT         0.15521        14.83594         0.01046         0.99165
# powiat policki_CONSTANT        28.94119        19.57038         1.47883         0.13926
# powiat polkowicki_CONSTANT         7.78289        19.58740         0.39734         0.69114
# powiat poznański_CONSTANT        26.64123         8.00903         3.32640         0.00089
# powiat proszowicki_CONSTANT        15.66105        13.69187         1.14382         0.25276
# powiat pruszkowski_CONSTANT        33.87162         8.50745         3.98141         0.00007
# powiat przeworski_CONSTANT        21.02836        16.57994         1.26830         0.20476
# powiat pszczyński_CONSTANT        19.78238        11.38914         1.73695         0.08247
# powiat pucki_CONSTANT        20.69838        14.83107         1.39561         0.16291
# powiat puławski_CONSTANT        16.05150        14.86519         1.07980         0.28029
# powiat pułtuski_CONSTANT        32.51778        19.60353         1.65877         0.09724
# powiat pyrzycki_CONSTANT        28.07070        26.62211         1.05441         0.29175
# powiat płocki_CONSTANT         5.59608        16.60216         0.33707         0.73608
# powiat płoński_CONSTANT         9.32836        13.10570         0.71178         0.47664
# powiat raciborski_CONSTANT        56.36923        14.84064         3.79830         0.00015
# powiat radomski_CONSTANT        11.84045        26.63492         0.44455         0.65667
# powiat radomszczański_CONSTANT        13.11741        12.27222         1.06887         0.28519
# powiat radzyński_CONSTANT        10.89802        19.57418         0.55675         0.57772
# powiat rawicki_CONSTANT        -6.13142        14.88909        -0.41181         0.68050
# powiat ropczycko-sędziszowski_CONSTANT        12.03804        16.62016         0.72430         0.46892
# powiat rybnicki_CONSTANT        20.36133        13.68644         1.48770         0.13690
# powiat rycki_CONSTANT        11.84045        26.63492         0.44455         0.65667
# powiat rypiński_CONSTANT        11.16419        16.57562         0.67353         0.50065
# powiat rzeszowski_CONSTANT         9.38102        10.40476         0.90161         0.36732
# powiat sandomierski_CONSTANT        -0.18833        16.57837        -0.01136         0.99094
# powiat sieradzki_CONSTANT        17.92680        26.62856         0.67322         0.50085
# powiat sierpecki_CONSTANT         6.13362        14.83869         0.41335         0.67937
# powiat sochaczewski_CONSTANT        36.45564        14.85419         2.45423         0.01416
# powiat sokołowski_CONSTANT        65.82606        19.58191         3.36157         0.00078
# powiat sokólski_CONSTANT        20.89802        19.57418         1.06763         0.28575
# powiat stalowowolski_CONSTANT        17.31395        13.71826         1.26211         0.20698
# powiat starachowicki_CONSTANT        31.14278        19.59407         1.58940         0.11204
# powiat stargardzki_CONSTANT        25.43402        11.78172         2.15877         0.03092
# powiat starogardzki_CONSTANT        36.26578        11.39169         3.18353         0.00147
# powiat strzelecki_CONSTANT         8.50712        16.57430         0.51327         0.60779
# powiat strzelecko-drezdenecki_CONSTANT        24.01314        19.56546         1.22732         0.21977
# powiat strzeliński_CONSTANT        23.54620        14.86812         1.58367         0.11334
# powiat szamotulski_CONSTANT        13.15257        12.87929         1.02122         0.30721
# powiat szczecinecki_CONSTANT        -1.98567        11.78170        -0.16854         0.86617
# powiat sztumski_CONSTANT        39.27499        13.69736         2.86734         0.00416
# powiat słubicki_CONSTANT        42.58326        14.84591         2.86835         0.00415
# powiat słupecki_CONSTANT        18.22625        11.78186         1.54698         0.12194
# powiat słupski_CONSTANT        15.91200        11.43960         1.39096         0.16431
# powiat tarnogórski_CONSTANT        20.21856        11.38488         1.77591         0.07582
# powiat tatrzański_CONSTANT        26.38937        11.39639         2.31559         0.02063
# powiat tomaszowski_CONSTANT         7.02759        10.80549         0.65037         0.51549
# powiat toruński_CONSTANT        27.71094        19.59794         1.41397         0.15744
# powiat trzebnicki_CONSTANT        -9.47480        13.03320        -0.72697         0.46728
# powiat wadowicki_CONSTANT        26.62224        11.37427         2.34057         0.01930
# powiat warszawski zachodni_CONSTANT        39.82132         9.19284         4.33178         0.00002
# powiat wałbrzyski_CONSTANT        35.89802        26.63047         1.34801         0.17773
# powiat wejherowski_CONSTANT        23.92101         8.44142         2.83377         0.00462
# powiat wielicki_CONSTANT        25.79253         9.78470         2.63601         0.00842
# powiat wieluński_CONSTANT         9.49572        26.70137         0.35563         0.72214
# powiat wodzisławski_CONSTANT        27.63386        11.15531         2.47719         0.01328
# powiat wolsztyński_CONSTANT        14.01314        26.62407         0.52633         0.59868
# powiat wołomiński_CONSTANT        32.25070         8.21150         3.92750         0.00009
# powiat wołowski_CONSTANT        -6.60185        19.62728        -0.33636         0.73662
# powiat wrocławski_CONSTANT        33.87925         8.59537         3.94157         0.00008
# powiat wrzesiński_CONSTANT         7.41307        10.18814         0.72762         0.46689
# powiat wysokomazowiecki_CONSTANT        53.27180        13.85136         3.84596         0.00012
# powiat wyszkowski_CONSTANT        31.84045        26.63492         1.19544         0.23198
# powiat wąbrzeski_CONSTANT         6.84045        26.63492         0.25682         0.79733
# powiat wągrowiecki_CONSTANT       -16.21711        26.64019        -0.60875         0.54273
# powiat węgorzewski_CONSTANT         4.01314        26.62407         0.15073         0.88019
# powiat węgrowski_CONSTANT        16.47834        16.57837         0.99397         0.32030
# powiat zambrowski_CONSTANT         6.66062        16.55820         0.40225         0.68752
# powiat zawierciański_CONSTANT        11.84045        26.63492         0.44455         0.65667
# powiat zduńskowolski_CONSTANT         5.79897        11.89317         0.48759         0.62587
# powiat zgierski_CONSTANT        11.37633         9.39304         1.21114         0.22591
# powiat zgorzelecki_CONSTANT        45.89802        19.57418         2.34482         0.01908
# powiat zielonogórski_CONSTANT        24.01314        26.62407         0.90193         0.36714
# powiat zwoleński_CONSTANT        22.05631        19.56336         1.12743         0.25962
# powiat złotowski_CONSTANT        -8.15955        26.63492        -0.30635         0.75935
# powiat Łomża_CONSTANT       123.43752        12.38540         9.96637         0.00000
# powiat Łódź_CONSTANT        24.76047         7.87259         3.14515         0.00167
# powiat łaski_CONSTANT        20.55663        11.77753         1.74541         0.08099
# powiat łańcucki_CONSTANT        18.64631        12.26559         1.52021         0.12853
# powiat łobeski_CONSTANT        29.88362        14.83869         2.01390         0.04408
# powiat łowicki_CONSTANT        20.52648        16.67306         1.23112         0.21835
# powiat łukowski_CONSTANT         8.45836        10.22574         0.82716         0.40819
# powiat łódzki wschodni_CONSTANT        24.86923        12.88043         1.93078         0.05358
# powiat łęczycki_CONSTANT        32.30953        13.69256         2.35964         0.01834
# powiat Świnoujście_CONSTANT        34.43046        13.69608         2.51389         0.01198
# powiat Świętochłowice_CONSTANT        12.40256        11.05400         1.12200         0.26193
# powiat średzki_CONSTANT        18.01633         9.79869         1.83865         0.06604
# powiat śremski_CONSTANT        11.95917        11.76520         1.01649         0.30946
# powiat świdnicki_CONSTANT        18.92775        10.36736         1.82570         0.06796
# powiat świebodziński_CONSTANT         9.88362        19.57558         0.50490         0.61366
# powiat świecki_CONSTANT        14.01314        26.62407         0.52633         0.59868
# powiat Żory_CONSTANT        15.89802        16.56715         0.95961         0.33731
# powiat żagański_CONSTANT        12.27217        26.62178         0.46098         0.64484
# powiat żarski_CONSTANT        37.32999        26.68546         1.39889         0.16192
# powiat żuromiński_CONSTANT         0.89802        19.57418         0.04588         0.96341
# powiat żyrardowski_CONSTANT        37.28705        14.84167         2.51232         0.01203
# powiat żywiecki_CONSTANT        18.58629        10.56306         1.75956         0.07856
# ------------------------------------------------------------------------------------
# Regimes variable: unknown
#
# REGIMES DIAGNOSTICS - CHOW TEST
#                  VARIABLE        DF        VALUE           PROB
#                  CONSTANT        278         953.950           0.0000
#               Global test        278         953.950           0.0000
#
# REGRESSION DIAGNOSTICS
# MULTICOLLINEARITY CONDITION NUMBER           54.222
#
# TEST ON NORMALITY OF ERRORS
# TEST                             DF        VALUE           PROB
# Jarque-Bera                       2      806398.845           0.0000
#
# DIAGNOSTICS FOR HETEROSKEDASTICITY
# RANDOM COEFFICIENTS
# TEST                             DF        VALUE           PROB
# Breusch-Pagan test               284       77296.069           0.0000
# Koenker-Bassett test             284        2301.759           0.0000
# ================================ END OF REPORT =====================================

# %%
# Build full table of regression coefficients
regimes_pow_hyb = pd.DataFrame(
    {
        # Pull out regression coefficients and
        # flatten as they are returned as Nx1 array
        "Coeff.": hyb_model_regimes_pow.betas.flatten(),
        # Pull out and flatten standard errors
        "Std. Error": hyb_model_regimes_pow.std_err.flatten(),
        # Pull out P-values from t-stat object
        "P-Value": [i[1] for i in hyb_model_regimes_pow.t_stat],
    },
    index=hyb_model_regimes_pow.name_x
    # Round to four decimals
).round(4)
regimes_pow_hyb
# Out:
#                                  Coeff.  Std. Error  P-Value
# powiat Biała Podlaska_CONSTANT  12.3405     19.5802   0.5286
# powiat Białystok_CONSTANT       18.1316      9.0068   0.0442
# powiat Bielsko-Biała_CONSTANT   21.6466      8.3309   0.0094
# powiat Bydgoszcz_CONSTANT       21.7593      8.0094   0.0066
# powiat Bytom_CONSTANT           35.7415      9.6630   0.0002
# ...                                 ...         ...      ...
# _Global_french                  12.5590      1.3917   0.0000
# _Global_hybrydowy               53.9296      3.3965   0.0000
# _Global_kolor                    1.5392      1.5117   0.3086
# _Global_manicure                -2.2881      6.9659   0.7426
# _Global_ze                       2.3447      1.8664   0.2091
#
# [285 rows x 3 columns]

# %%
#max features = 7
powiaty_hybrydy = cv_function(result_gdf_hybrydy_pow, 'Description', 7)
variable_names = list(powiaty_hybrydy.columns.difference(columns_to_exclude))

hyb_model_regimes_pow_7 = regression_regimes(powiaty_hybrydy, 'Price', variable_names, 'District')
print(hyb_model_regimes_pow_7.summary)
# Out:
# d:\2sem\pdp\.venv\lib\site-packages\spreg\diagnostics.py:607: ComplexWarning: Casting complex values to real discards the imaginary part
#   ci_result = sqrt(max_eigval / min_eigval)
# REGRESSION RESULTS
# ------------------
#
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES - REGIMES
# ---------------------------------------------------
# Data set            :     unknown
# Weights matrix      :        None
# Dependent Variable  :       Price                Number of Observations:        4536
# Mean dependent var  :    116.7315                Number of Variables   :         287
# S.D. dependent var  :     31.2829                Degrees of Freedom    :        4249
# R-squared           :      0.3773
# Adjusted R-squared  :      0.3354
# Sum squared residual: 2.76368e+06                F-statistic           :      9.0009
# Sigma-square        :     650.430                Prob(F-statistic)     :  9.731e-269
# S.E. of regression  :      25.504                Log likelihood        :  -20979.338
# Sigma-square ML     :     609.276                Akaike info criterion :   42532.676
# S.E of regression ML:     24.6835                Schwarz criterion     :   44375.159
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     t-Statistic     Probability
# ------------------------------------------------------------------------------------
#     _Global_Duration         0.40663         0.01485        27.37541         0.00000
#       _Global_french        12.88882         1.39303         9.25239         0.00000
#    _Global_hybrydowy        53.97302         3.39227        15.91059         0.00000
#      _Global_hybrydy         4.52540         2.02613         2.23352         0.02557
#        _Global_kolor         1.67555         1.51036         1.10937         0.26733
#     _Global_manicure        -2.04827         6.95751        -0.29440         0.76847
#    _Global_nadbudową         6.22508         2.18869         2.84420         0.00447
#           _Global_ze         1.64473         1.90819         0.86193         0.38877
# powiat Biała Podlaska_CONSTANT        11.97881        19.55600         0.61254         0.54021
# powiat Białystok_CONSTANT        17.43236         8.99774         1.93742         0.05276
# powiat Bielsko-Biała_CONSTANT        21.07747         8.32200         2.53274         0.01135
# powiat Bydgoszcz_CONSTANT        21.11564         8.00177         2.63887         0.00835
# powiat Bytom_CONSTANT        35.40985         9.65137         3.66889         0.00025
# powiat Chełm_CONSTANT        16.39117        26.66426         0.61472         0.53877
# powiat Chorzów_CONSTANT        20.86378         9.90191         2.10705         0.03517
# powiat Częstochowa_CONSTANT        19.70483         8.85603         2.22502         0.02613
# powiat Dąbrowa Górnicza_CONSTANT        24.35221        10.71575         2.27256         0.02310
# powiat Elbląg_CONSTANT        14.74966        11.37151         1.29707         0.19468
# powiat Gdańsk_CONSTANT        32.09694         7.80590         4.11188         0.00004
# powiat Gdynia_CONSTANT        33.56127         7.96078         4.21583         0.00003
# powiat Gliwice_CONSTANT        23.02202         8.63215         2.66701         0.00768
# powiat Gorzów Wielkopolski_CONSTANT        21.85161        10.03704         2.17710         0.02953
# powiat Grudziądz_CONSTANT        22.06888        10.03192         2.19987         0.02787
# powiat Jastrzębie-Zdrój_CONSTANT         8.74538        14.82451         0.58993         0.55527
# powiat Jaworzno_CONSTANT        18.48562        10.03906         1.84137         0.06564
# powiat Jelenia Góra_CONSTANT        35.75170        10.54696         3.38976         0.00071
# powiat Kalisz_CONSTANT        18.69679         9.27996         2.01475         0.04399
# powiat Katowice_CONSTANT        29.05305         7.98688         3.63760         0.00028
# powiat Kielce_CONSTANT        21.06815        10.54511         1.99791         0.04579
# powiat Konin_CONSTANT        24.80277        10.03577         2.47144         0.01350
# powiat Koszalin_CONSTANT        25.98923         9.08230         2.86153         0.00424
# powiat Kraków_CONSTANT        33.75769         7.85427         4.29800         0.00002
# powiat Krosno_CONSTANT        -4.25957        12.24609        -0.34783         0.72798
# powiat bolesławiecki_CONSTANT        22.02851        14.82051         1.48635         0.13726
# powiat brodnicki_CONSTANT        33.53854        10.38793         3.22861         0.00125
# powiat brzeski_CONSTANT        12.03652        10.36870         1.16085         0.24577
# powiat brzeziński_CONSTANT        40.37940        19.56722         2.06362         0.03911
# powiat brzozowski_CONSTANT         5.37940        26.60998         0.20216         0.83980
# powiat buski_CONSTANT        58.87841        16.54675         3.55831         0.00038
# powiat bydgoski_CONSTANT        19.08591        11.37118         1.67845         0.09333
# powiat będziński_CONSTANT        17.04232        10.54497         1.61616         0.10613
# powiat chełmiński_CONSTANT        23.97881        14.82666         1.61728         0.10589
# powiat chojnicki_CONSTANT        -1.42178        19.54732        -0.07274         0.94202
# powiat choszczeński_CONSTANT        17.57822        26.59535         0.66095         0.50868
# powiat chrzanowski_CONSTANT        11.25542         9.39353         1.19821         0.23090
# powiat ciechanowski_CONSTANT         0.50482        11.39785         0.04429         0.96467
# powiat cieszyński_CONSTANT         9.06824        10.04527         0.90274         0.36672
# powiat czarnkowsko-trzcianecki_CONSTANT         1.47881        26.60174         0.05559         0.95567
# powiat częstochowski_CONSTANT        17.86025        16.56403         1.07825         0.28098
# powiat człuchowski_CONSTANT        12.35833        13.67584         0.90366         0.36623
# powiat działdowski_CONSTANT         9.44567        26.60428         0.35504         0.72257
# powiat dzierżoniowski_CONSTANT         2.49538        11.76701         0.21207         0.83207
# powiat dąbrowski_CONSTANT        19.55613        16.54568         1.18195         0.23729
# powiat dębicki_CONSTANT        35.10179        10.16641         3.45272         0.00056
# powiat ełcki_CONSTANT        26.71271        14.84508         1.79943         0.07202
# powiat garwoliński_CONSTANT        13.12033        13.67826         0.95921         0.33751
# powiat gdański_CONSTANT        20.26916         8.89182         2.27953         0.02269
# powiat gliwicki_CONSTANT        25.63505        11.75640         2.18052         0.02927
# powiat gnieźnieński_CONSTANT         6.98114        12.27036         0.56894         0.56942
# powiat golubsko-dobrzyński_CONSTANT         4.25372        26.69503         0.15935         0.87340
# powiat gorzowski_CONSTANT       155.44962        16.70894         9.30338         0.00000
# powiat gostyński_CONSTANT         9.63086        14.82138         0.64980         0.51586
# powiat gołdapski_CONSTANT        -0.72001        26.62009        -0.02705         0.97842
# powiat grodziski_CONSTANT        30.84924         8.55220         3.60717         0.00031
# powiat grójecki_CONSTANT        51.66611        10.36053         4.98682         0.00000
# powiat głogowski_CONSTANT        22.26697        16.54179         1.34610         0.17834
# powiat głubczycki_CONSTANT        25.58650        14.81440         1.72714         0.08422
# powiat hajnowski_CONSTANT        28.64841        16.55273         1.73074         0.08357
# powiat hrubieszowski_CONSTANT        11.36042        12.89824         0.88077         0.37849
# powiat inowrocławski_CONSTANT        16.35681        13.70754         1.19327         0.23283
# powiat iławski_CONSTANT        17.57822        26.59535         0.66095         0.50868
# powiat jarociński_CONSTANT        -4.25413        16.56242        -0.25685         0.79730
# powiat jarosławski_CONSTANT        32.56106        14.84042         2.19408         0.02828
# powiat jasielski_CONSTANT       -21.76041        14.82557        -1.46776         0.14224
# powiat kamieński_CONSTANT        11.47881        26.60174         0.43151         0.66612
# powiat kartuski_CONSTANT        29.56831        10.81854         2.73312         0.00630
# powiat kielecki_CONSTANT        18.13524        12.89517         1.40636         0.15969
# powiat kluczborski_CONSTANT        32.13742        11.78522         2.72693         0.00642
# powiat kolski_CONSTANT        -5.29270        19.57132        -0.27043         0.78684
# powiat koniński_CONSTANT        21.03404        16.54785         1.27110         0.20376
# powiat kozienicki_CONSTANT        45.30284        11.05661         4.09735         0.00004
# powiat kołobrzeski_CONSTANT        37.17837        10.02847         3.70728         0.00021
# powiat kościański_CONSTANT         6.65590        12.88304         0.51664         0.60543
# powiat kościerski_CONSTANT         9.83976        12.86557         0.76481         0.44443
# powiat krakowski_CONSTANT        28.84020         8.62459         3.34395         0.00083
# powiat krapkowicki_CONSTANT        29.18966        16.54899         1.76383         0.07783
# powiat kraśnicki_CONSTANT        19.24835        12.77903         1.50625         0.13208
# powiat krotoszyński_CONSTANT        23.59478        14.81362         1.59278         0.11128
# powiat krośnieński_CONSTANT        12.02851        19.55134         0.61523         0.53844
# powiat kutnowski_CONSTANT        20.06286        14.84845         1.35118         0.17671
# powiat kwidzyński_CONSTANT        41.99049        16.57607         2.53320         0.01134
# powiat kędzierzyńsko-kozielski_CONSTANT        21.80851        19.62656         1.11117         0.26656
# powiat kępiński_CONSTANT         6.31605        16.60990         0.38026         0.70377
# powiat kłobucki_CONSTANT        19.24927        13.67921         1.40719         0.15944
# powiat kłodzki_CONSTANT        16.11234        16.55800         0.97308         0.33057
# powiat legionowski_CONSTANT        28.72875         8.97352         3.20150         0.00138
# powiat legnicki_CONSTANT         2.57822        19.54732         0.13190         0.89507
# powiat leszczyński_CONSTANT       -17.22757        14.81998        -1.16246         0.24512
# powiat leżajski_CONSTANT       -22.42178        26.59535        -0.84307         0.39924
# powiat limanowski_CONSTANT         1.81214        16.55392         0.10947         0.91284
# powiat lubartowski_CONSTANT        14.55613        12.85903         1.13198         0.25771
# powiat lubański_CONSTANT        21.76368        16.55047         1.31499         0.18858
# powiat lubelski_CONSTANT        34.04650        13.71815         2.48186         0.01311
# powiat lubiński_CONSTANT        23.16248         9.48489         2.44204         0.01465
# powiat lubliniecki_CONSTANT         6.24488        16.54366         0.37748         0.70584
# powiat lwówecki_CONSTANT        18.59478        19.54612         0.95133         0.34149
# powiat lęborski_CONSTANT        10.12617        13.70629         0.73880         0.46007
# powiat makowski_CONSTANT        -8.52119        26.60174        -0.32032         0.74874
# powiat malborski_CONSTANT        20.24356        11.77332         1.71944         0.08561
# powiat miechowski_CONSTANT         5.64449        19.54294         0.28882         0.77273
# powiat mielecki_CONSTANT        15.80277        10.98596         1.43845         0.15038
# powiat mikołowski_CONSTANT         3.51194        19.55283         0.17961         0.85746
# powiat milicki_CONSTANT        15.54508        14.81865         1.04902         0.29423
# powiat międzychodzki_CONSTANT        13.67762        26.59084         0.51437         0.60702
# powiat międzyrzecki_CONSTANT         6.47881        26.60174         0.24355         0.80759
# powiat miński_CONSTANT        27.06694         9.26203         2.92235         0.00349
# powiat mogileński_CONSTANT        37.99035        14.69605         2.58507         0.00977
# powiat mrągowski_CONSTANT        15.54508        26.59727         0.58446         0.55894
# powiat myszkowski_CONSTANT       -13.68687        19.57610        -0.69916         0.48449
# powiat myślenicki_CONSTANT        19.87121        10.81397         1.83755         0.06620
# powiat mławski_CONSTANT        27.23776        16.55940         1.64485         0.10007
# powiat nakielski_CONSTANT        19.57630        13.69764         1.42917         0.15303
# powiat nowodworski_CONSTANT        16.82795         9.89513         1.70063         0.08909
# powiat nowomiejski_CONSTANT         5.81165        19.54859         0.29729         0.76626
# powiat nowosolski_CONSTANT        18.14548        16.55392         1.09614         0.27308
# powiat nowosądecki_CONSTANT        -0.00462        14.82451        -0.00031         0.99975
# powiat nowotarski_CONSTANT        18.16220        11.37722         1.59636         0.11048
# powiat nowotomyski_CONSTANT         9.35828        12.87085         0.72709         0.46721
# powiat nyski_CONSTANT        25.39501        11.79774         2.15253         0.03141
# powiat obornicki_CONSTANT        19.23786        13.66794         1.40752         0.15935
# powiat olecki_CONSTANT        -2.42178        19.54732        -0.12389         0.90141
# powiat oleski_CONSTANT        41.47881        26.60174         1.55925         0.11901
# powiat oleśnicki_CONSTANT        23.91815        11.37234         2.10319         0.03551
# powiat olkuski_CONSTANT        18.20997        13.68461         1.33069         0.18336
# powiat olsztyński_CONSTANT        22.44973        13.68010         1.64105         0.10086
# powiat opolski_CONSTANT        55.41880        12.27029         4.51650         0.00001
# powiat ostrowiecki_CONSTANT        13.70502        10.54917         1.29916         0.19396
# powiat ostrowski_CONSTANT        14.01992         8.84328         1.58537         0.11296
# powiat ostrzeszowski_CONSTANT        11.98469        19.57962         0.61210         0.54050
# powiat ostródzki_CONSTANT        24.81214        12.86962         1.92796         0.05393
# powiat otwocki_CONSTANT        16.53875         9.75467         1.69547         0.09006
# powiat oławski_CONSTANT        45.06342        11.06522         4.07253         0.00005
# powiat oświęcimski_CONSTANT        25.81993         9.87720         2.61409         0.00898
# powiat pabianicki_CONSTANT        24.75781        10.19524         2.42837         0.01521
# powiat pajęczański_CONSTANT        12.57822        26.59535         0.47295         0.63627
# powiat piaseczyński_CONSTANT        33.59807         8.33692         4.03003         0.00006
# powiat pilski_CONSTANT        22.85614        12.24685         1.86629         0.06207
# powiat piotrkowski_CONSTANT         9.61135        26.59364         0.36142         0.71781
# powiat piski_CONSTANT        36.59786        19.37801         1.88863         0.05901
# powiat pleszewski_CONSTANT        -0.19664        14.81775        -0.01327         0.98941
# powiat policki_CONSTANT        28.59478        19.54612         1.46294         0.14356
# powiat polkowicki_CONSTANT         7.41254        19.56320         0.37890         0.70478
# powiat poznański_CONSTANT        25.59573         8.00468         3.19760         0.00140
# powiat proszowicki_CONSTANT        15.25347        13.67526         1.11541         0.26474
# powiat pruszkowski_CONSTANT        33.18751         8.50049         3.90419         0.00010
# powiat przeworski_CONSTANT        20.54473        16.55975         1.24064         0.21481
# powiat pszczyński_CONSTANT        19.37862        11.37557         1.70353         0.08854
# powiat pucki_CONSTANT        18.79680        14.82459         1.26795         0.20489
# powiat puławski_CONSTANT        15.57115        14.84730         1.04875         0.29435
# powiat pułtuski_CONSTANT        31.98469        19.57962         1.63357         0.10242
# powiat pyrzycki_CONSTANT        27.74390        26.58886         1.04344         0.29680
# powiat płocki_CONSTANT         5.16098        16.58187         0.31124         0.75563
# powiat płoński_CONSTANT         8.94335        13.08984         0.68323         0.49450
# powiat raciborski_CONSTANT        56.01194        14.82247         3.77885         0.00016
# powiat radomski_CONSTANT        11.47881        26.60174         0.43151         0.66612
# powiat radomszczański_CONSTANT        11.54706        12.27353         0.94081         0.34686
# powiat radzyński_CONSTANT        10.54508        19.54993         0.53939         0.58964
# powiat rawicki_CONSTANT        -6.70076        14.87146        -0.45058         0.65232
# powiat ropczycko-sędziszowski_CONSTANT        11.48720        16.60015         0.69199         0.48898
# powiat rybnicki_CONSTANT        20.01798        13.66970         1.46441         0.14316
# powiat rycki_CONSTANT        11.47881        26.60174         0.43151         0.66612
# powiat rypiński_CONSTANT         8.72607        16.57313         0.52652         0.59856
# powiat rzeszowski_CONSTANT         6.58637        10.43132         0.63140         0.52781
# powiat sandomierski_CONSTANT        -0.55433        16.55800        -0.03348         0.97330
# powiat sieradzki_CONSTANT        17.57822        26.59535         0.66095         0.50868
# powiat sierpecki_CONSTANT         4.22224        14.83218         0.28467         0.77591
# powiat sochaczewski_CONSTANT        36.05992        14.83610         2.43055         0.01512
# powiat sokołowski_CONSTANT        65.46224        19.55770         3.34713         0.00082
# powiat sokólski_CONSTANT        20.54508        19.54993         1.05090         0.29336
# powiat stalowowolski_CONSTANT        17.08359        13.70118         1.24687         0.21251
# powiat starachowicki_CONSTANT        30.72387        19.56992         1.56995         0.11650
# powiat stargardzki_CONSTANT        24.28265        11.77179         2.06278         0.03919
# powiat starogardzki_CONSTANT        34.47635        11.40174         3.02378         0.00251
# powiat strzelecki_CONSTANT         8.14548        16.55392         0.49206         0.62270
# powiat strzelecko-drezdenecki_CONSTANT        23.67762        19.54117         1.21168         0.22570
# powiat strzeliński_CONSTANT        21.49510        14.86299         1.44622         0.14819
# powiat szamotulski_CONSTANT        12.74684        12.86376         0.99091         0.32179
# powiat szczecinecki_CONSTANT        -2.96200        11.77295        -0.25159         0.80137
# powiat sztumski_CONSTANT        38.91857        13.68066         2.84479         0.00447
# powiat słubicki_CONSTANT        42.22052        14.82776         2.84740         0.00443
# powiat słupecki_CONSTANT        17.86623        11.76767         1.51825         0.12903
# powiat słupski_CONSTANT        14.52637        11.43852         1.26995         0.20417
# powiat tarnogórski_CONSTANT        19.86369        11.37118         1.74684         0.08074
# powiat tatrzański_CONSTANT        26.03898        11.38252         2.28763         0.02221
# powiat tomaszowski_CONSTANT         6.30499        10.79529         0.58405         0.55922
# powiat toruński_CONSTANT        27.32970        19.57378         1.39624         0.16272
# powiat trzebnicki_CONSTANT        -9.90882        13.01761        -0.76119         0.44659
# powiat wadowicki_CONSTANT        25.58634        11.36408         2.25151         0.02440
# powiat warszawski zachodni_CONSTANT        38.29339         9.19207         4.16591         0.00003
# powiat wałbrzyski_CONSTANT        35.54508        26.59727         1.33642         0.18148
# powiat wejherowski_CONSTANT        23.25402         8.43329         2.75741         0.00585
# powiat wielicki_CONSTANT        25.11002         9.77554         2.56866         0.01024
# powiat wieluński_CONSTANT         9.83407        26.66960         0.36874         0.71234
# powiat wodzisławski_CONSTANT        27.26034        11.14197         2.44664         0.01446
# powiat wolsztyński_CONSTANT        13.67762        26.59084         0.51437         0.60702
# powiat wołomiński_CONSTANT        30.50638         8.21578         3.71314         0.00021
# powiat wołowski_CONSTANT        -7.05778        19.60324        -0.36003         0.71884
# powiat wrocławski_CONSTANT        33.20564         8.58669         3.86711         0.00011
# powiat wrzesiński_CONSTANT         7.03409        10.17609         0.69124         0.48945
# powiat wysokomazowiecki_CONSTANT        52.90409        13.83450         3.82407         0.00013
# powiat wyszkowski_CONSTANT        25.25372        26.69503         0.94601         0.34420
# powiat wąbrzeski_CONSTANT         6.47881        26.60174         0.24355         0.80759
# powiat wągrowiecki_CONSTANT       -22.81255        26.70019        -0.85440         0.39293
# powiat węgorzewski_CONSTANT         3.67762        26.59084         0.13830         0.89001
# powiat węgrowski_CONSTANT        14.03731        16.57587         0.84685         0.39713
# powiat zambrowski_CONSTANT         6.32220        16.53775         0.38229         0.70227
# powiat zawierciański_CONSTANT         5.25372        26.69503         0.19681         0.84399
# powiat zduńskowolski_CONSTANT         5.51831        11.87852         0.46456         0.64227
# powiat zgierski_CONSTANT        10.05145         9.38864         1.07060         0.28441
# powiat zgorzelecki_CONSTANT        45.54508        19.54993         2.32968         0.01987
# powiat zielonogórski_CONSTANT        23.67762        26.59084         0.89044         0.37328
# powiat zwoleński_CONSTANT        21.72733        19.53905         1.11199         0.26620
# powiat złotowski_CONSTANT        -8.52119        26.60174        -0.32032         0.74874
# powiat Łomża_CONSTANT       122.12561        12.37561         9.86825         0.00000
# powiat Łódź_CONSTANT        24.02687         7.86618         3.05445         0.00227
# powiat łaski_CONSTANT        19.68756        11.76717         1.67309         0.09438
# powiat łańcucki_CONSTANT        18.26128        12.25080         1.49062         0.13614
# powiat łobeski_CONSTANT        29.52851        14.82051         1.99241         0.04639
# powiat łowicki_CONSTANT        20.03041        16.65301         1.20281         0.22912
# powiat łukowski_CONSTANT         8.07927        10.21347         0.79104         0.42896
# powiat łódzki wschodni_CONSTANT        24.51194        12.86480         1.90535         0.05680
# powiat łęczycki_CONSTANT        29.46830        13.70660         2.14994         0.03162
# powiat Świnoujście_CONSTANT        34.05636        13.67941         2.48961         0.01283
# powiat Świętochłowice_CONSTANT        12.02578        11.04076         1.08922         0.27612
# powiat średzki_CONSTANT        17.32612         9.78843         1.77006         0.07679
# powiat śremski_CONSTANT        11.04982        11.75588         0.93994         0.34730
# powiat świdnicki_CONSTANT        18.61913        10.35472         1.79813         0.07223
# powiat świebodziński_CONSTANT         6.41597        19.58433         0.32761         0.74322
# powiat świecki_CONSTANT        13.67762        26.59084         0.51437         0.60702
# powiat Żory_CONSTANT        15.54508        16.54675         0.93946         0.34755
# powiat żagański_CONSTANT        11.97585        26.58849         0.45041         0.65243
# powiat żarski_CONSTANT        30.61131        26.74747         1.14446         0.25250
# powiat żuromiński_CONSTANT         0.54508        19.54993         0.02788         0.97776
# powiat żyrardowski_CONSTANT        36.85601        14.82365         2.48630         0.01295
# powiat żywiecki_CONSTANT        17.70070        10.55283         1.67734         0.09355
# ------------------------------------------------------------------------------------
# Regimes variable: unknown
#
# REGIMES DIAGNOSTICS - CHOW TEST
#                  VARIABLE        DF        VALUE           PROB
#                  CONSTANT        278         929.424           0.0000
#               Global test        278         929.424           0.0000
#
# REGRESSION DIAGNOSTICS
# MULTICOLLINEARITY CONDITION NUMBER           54.857
#
# TEST ON NORMALITY OF ERRORS
# TEST                             DF        VALUE           PROB
# Jarque-Bera                       2      822127.551           0.0000
#
# DIAGNOSTICS FOR HETEROSKEDASTICITY
# RANDOM COEFFICIENTS
# TEST                             DF        VALUE           PROB
# Breusch-Pagan test               286       78084.019           0.0000
# Koenker-Bassett test             286        2303.528           0.0000
# ================================ END OF REPORT =====================================

# %%
# Build full table of regression coefficients
regimes_pow_7_hyb = pd.DataFrame(
    {
        # Pull out regression coefficients and
        # flatten as they are returned as Nx1 array
        "Coeff.": hyb_model_regimes_pow_7.betas.flatten(),
        # Pull out and flatten standard errors
        "Std. Error": hyb_model_regimes_pow_7.std_err.flatten(),
        # Pull out P-values from t-stat object
        "P-Value": [i[1] for i in hyb_model_regimes_pow_7.t_stat],
    },
    index=hyb_model_regimes_pow_7.name_x
    # Round to four decimals
).round(4)
regimes_pow_7_hyb
# Out:
#                                  Coeff.  Std. Error  P-Value
# powiat Biała Podlaska_CONSTANT  11.9788     19.5560   0.5402
# powiat Białystok_CONSTANT       17.4324      8.9977   0.0528
# powiat Bielsko-Biała_CONSTANT   21.0775      8.3220   0.0114
# powiat Bydgoszcz_CONSTANT       21.1156      8.0018   0.0083
# powiat Bytom_CONSTANT           35.4098      9.6514   0.0002
# ...                                 ...         ...      ...
# _Global_hybrydy                  4.5254      2.0261   0.0256
# _Global_kolor                    1.6756      1.5104   0.2673
# _Global_manicure                -2.0483      6.9575   0.7685
# _Global_nadbudową                6.2251      2.1887   0.0045
# _Global_ze                       1.6447      1.9082   0.3888
#
# [287 rows x 3 columns]

# %% [markdown]
# ## woje

# %%
wojewodztwa_hybrydy = cv_function(result_gdf_hybrydy_woj, 'Description', 5)
columns_to_exclude = ['Location', 'Price','District', 'geometry', 'Description']
variable_names = list(wojewodztwa_hybrydy.columns.difference(columns_to_exclude))

# %%
wojewodztwa_hybrydy.head(2)
# Out:
#                       Description  Duration  \
# 0              manicure hybrydowy       120
# 1  manicure hybrydowy baby boomer       180
#
#                                             Location  Price  \
# 0  Generała Władysława Sikorskiego 14, 09-410, Płock  120.0
# 1  Generała Władysława Sikorskiego 14, 09-410, Płock  170.0
#
#                     geometry     District  french  hybrydowy  kolor  manicure  \
# 0  POINT (19.75517 52.53789)  mazowieckie       0          1      0         1
# 1  POINT (19.75517 52.53789)  mazowieckie       0          1      0         1
#
#    ze
# 0   0
# 1   0

# %%
hyb_model_base_woj = regression_base(wojewodztwa_hybrydy,'Price',variable_names)
print(hyb_model_base_woj.summary)
# Out:
# REGRESSION RESULTS
# ------------------
#
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES
# -----------------------------------------
# Data set            :     unknown
# Weights matrix      :        None
# Dependent Variable  :       Price                Number of Observations:        4536
# Mean dependent var  :    116.7315                Number of Variables   :           7
# S.D. dependent var  :     31.2829                Degrees of Freedom    :        4529
# R-squared           :      0.2353
# Adjusted R-squared  :      0.2342
# Sum squared residual: 3.39398e+06                F-statistic           :    232.2043
# Sigma-square        :     749.388                Prob(F-statistic)     :  2.392e-259
# S.E. of regression  :      27.375                Log likelihood        :  -21445.276
# Sigma-square ML     :     748.231                Akaike info criterion :   42904.553
# S.E of regression ML:     27.3538                Schwarz criterion     :   42949.491
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     t-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT        25.92433         7.98489         3.24668         0.00118
#             Duration         0.45094         0.01516        29.74900         0.00000
#               french        12.43307         1.45447         8.54818         0.00000
#            hybrydowy        53.12451         3.52250        15.08147         0.00000
#                kolor        -0.32031         1.55001        -0.20665         0.83629
#             manicure        -3.63976         7.33985        -0.49589         0.62000
#                   ze         3.43604         1.95251         1.75981         0.07851
# ------------------------------------------------------------------------------------
#
# REGRESSION DIAGNOSTICS
# MULTICOLLINEARITY CONDITION NUMBER           53.250
#
# TEST ON NORMALITY OF ERRORS
# TEST                             DF        VALUE           PROB
# Jarque-Bera                       2     1092631.055           0.0000
#
# DIAGNOSTICS FOR HETEROSKEDASTICITY
# RANDOM COEFFICIENTS
# TEST                             DF        VALUE           PROB
# Breusch-Pagan test                6       65395.946           0.0000
# Koenker-Bassett test              6        1680.901           0.0000
# ================================ END OF REPORT =====================================

# %%
# Build full table of regression coefficients
base_woj_hyb = pd.DataFrame(
    {
        # Pull out regression coefficients and
        # flatten as they are returned as Nx1 array
        "Coeff.": hyb_model_base_woj.betas.flatten(),
        # Pull out and flatten standard errors
        "Std. Error": hyb_model_base_woj.std_err.flatten(),
        # Pull out P-values from t-stat object
        "P-Value": [i[1] for i in hyb_model_base_woj.t_stat],
    },
    index=hyb_model_base_woj.name_x
    # Round to four decimals
).round(4)
base_woj_hyb
# Out:
#             Coeff.  Std. Error  P-Value
# CONSTANT   25.9243      7.9849   0.0012
# Duration    0.4509      0.0152   0.0000
# french     12.4331      1.4545   0.0000
# hybrydowy  53.1245      3.5225   0.0000
# kolor      -0.3203      1.5500   0.8363
# manicure   -3.6398      7.3398   0.6200
# ze          3.4360      1.9525   0.0785

# %%
hyb_model_regimes_woj = regression_regimes(wojewodztwa_hybrydy, 'Price', variable_names, 'District')
print(hyb_model_regimes_woj.summary)
# Out:
# REGRESSION RESULTS
# ------------------
#
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES - REGIMES
# ---------------------------------------------------
# Data set            :     unknown
# Weights matrix      :        None
# Dependent Variable  :       Price                Number of Observations:        4536
# Mean dependent var  :    116.7315                Number of Variables   :          22
# S.D. dependent var  :     31.2829                Degrees of Freedom    :        4514
# R-squared           :      0.2716
# Adjusted R-squared  :      0.2682
# Sum squared residual: 3.23255e+06                F-statistic           :     80.1607
# Sigma-square        :     716.117                Prob(F-statistic)     :  5.944e-291
# S.E. of regression  :      26.760                Log likelihood        :  -21334.755
# Sigma-square ML     :     712.644                Akaike info criterion :   42713.510
# S.E of regression ML:     26.6954                Schwarz criterion     :   42854.746
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     t-Statistic     Probability
# ------------------------------------------------------------------------------------
#     _Global_Duration         0.44772         0.01490        30.05264         0.00000
#       _Global_french        12.40582         1.42495         8.70614         0.00000
#    _Global_hybrydowy        52.11643         3.45139        15.10012         0.00000
#        _Global_kolor         1.01229         1.52355         0.66443         0.50645
#     _Global_manicure        -3.21309         7.19099        -0.44682         0.65503
#           _Global_ze         2.33476         1.91787         1.21737         0.22353
# dolnośląskie_CONSTANT        25.45166         7.97344         3.19206         0.00142
# kujawsko-pomorskie_CONSTANT        23.92627         7.98045         2.99811         0.00273
#   lubelskie_CONSTANT        17.07676         8.07754         2.11410         0.03456
#    lubuskie_CONSTANT        25.72999         8.32842         3.08942         0.00202
# mazowieckie_CONSTANT        36.05129         7.85880         4.58738         0.00000
# małopolskie_CONSTANT        25.47840         7.91700         3.21819         0.00130
#    opolskie_CONSTANT        29.10340         8.58080         3.39169         0.00070
# podkarpackie_CONSTANT        21.79892         8.07709         2.69886         0.00698
#   podlaskie_CONSTANT        35.74624         8.63791         4.13830         0.00004
#   pomorskie_CONSTANT        29.29952         7.90425         3.70681         0.00021
# warmińsko-mazurskie_CONSTANT        22.05174         8.45072         2.60945         0.00910
# wielkopolskie_CONSTANT        21.51109         7.86810         2.73396         0.00628
# zachodniopomorskie_CONSTANT        25.45497         8.12179         3.13416         0.00173
#     łódzkie_CONSTANT        20.39435         8.00953         2.54626         0.01092
#     śląskie_CONSTANT        22.12777         7.89206         2.80380         0.00507
# świętokrzyskie_CONSTANT        19.87989         8.91972         2.22876         0.02588
# ------------------------------------------------------------------------------------
# Regimes variable: unknown
#
# REGIMES DIAGNOSTICS - CHOW TEST
#                  VARIABLE        DF        VALUE           PROB
#                  CONSTANT        15         225.418           0.0000
#               Global test        15         225.418           0.0000
#
# REGRESSION DIAGNOSTICS
# MULTICOLLINEARITY CONDITION NUMBER           53.354
#
# TEST ON NORMALITY OF ERRORS
# TEST                             DF        VALUE           PROB
# Jarque-Bera                       2     1225952.927           0.0000
#
# DIAGNOSTICS FOR HETEROSKEDASTICITY
# RANDOM COEFFICIENTS
# TEST                             DF        VALUE           PROB
# Breusch-Pagan test               21       70213.259           0.0000
# Koenker-Bassett test             21        1706.084           0.0000
# ================================ END OF REPORT =====================================
# d:\2sem\pdp\.venv\lib\site-packages\spreg\diagnostics.py:607: ComplexWarning: Casting complex values to real discards the imaginary part
#   ci_result = sqrt(max_eigval / min_eigval)

# %%
# Build full table of regression coefficients
regimes_woj_hyb = pd.DataFrame(
    {
        # Pull out regression coefficients and
        # flatten as they are returned as Nx1 array
        "Coeff.": hyb_model_regimes_woj.betas.flatten(),
        # Pull out and flatten standard errors
        "Std. Error": hyb_model_regimes_woj.std_err.flatten(),
        # Pull out P-values from t-stat object
        "P-Value": [i[1] for i in hyb_model_regimes_woj.t_stat],
    },
    index=hyb_model_regimes_woj.name_x
    # Round to four decimals
).round(4)
regimes_woj_hyb
# Out:
#                                Coeff.  Std. Error  P-Value
# dolnośląskie_CONSTANT         25.4517      7.9734   0.0014
# kujawsko-pomorskie_CONSTANT   23.9263      7.9804   0.0027
# lubelskie_CONSTANT            17.0768      8.0775   0.0346
# lubuskie_CONSTANT             25.7300      8.3284   0.0020
# mazowieckie_CONSTANT          36.0513      7.8588   0.0000
# małopolskie_CONSTANT          25.4784      7.9170   0.0013
# opolskie_CONSTANT             29.1034      8.5808   0.0007
# podkarpackie_CONSTANT         21.7989      8.0771   0.0070
# podlaskie_CONSTANT            35.7462      8.6379   0.0000
# pomorskie_CONSTANT            29.2995      7.9043   0.0002
# warmińsko-mazurskie_CONSTANT  22.0517      8.4507   0.0091
# wielkopolskie_CONSTANT        21.5111      7.8681   0.0063
# zachodniopomorskie_CONSTANT   25.4550      8.1218   0.0017
# łódzkie_CONSTANT              20.3944      8.0095   0.0109
# śląskie_CONSTANT              22.1278      7.8921   0.0051
# świętokrzyskie_CONSTANT       19.8799      8.9197   0.0259
# _Global_Duration               0.4477      0.0149   0.0000
# _Global_french                12.4058      1.4250   0.0000
# _Global_hybrydowy             52.1164      3.4514   0.0000
# _Global_kolor                  1.0123      1.5235   0.5064
# _Global_manicure              -3.2131      7.1910   0.6550
# _Global_ze                     2.3348      1.9179   0.2235

# %%
#max features = 7
wojewodztwa_hybrydy = cv_function(result_gdf_hybrydy_woj, 'Description', 7)
variable_names = list(wojewodztwa_hybrydy.columns.difference(columns_to_exclude))

hyb_model_regimes_woj_7 = regression_regimes(wojewodztwa_hybrydy, 'Price', variable_names, 'District')
print(hyb_model_regimes_woj_7.summary)
# Out:
# REGRESSION RESULTS
# ------------------
#
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES - REGIMES
# ---------------------------------------------------
# Data set            :     unknown
# Weights matrix      :        None
# Dependent Variable  :       Price                Number of Observations:        4536
# Mean dependent var  :    116.7315                Number of Variables   :          24
# S.D. dependent var  :     31.2829                Degrees of Freedom    :        4512
# R-squared           :      0.2743
# Adjusted R-squared  :      0.2706
# Sum squared residual: 3.22057e+06                F-statistic           :     74.1596
# Sigma-square        :     713.779                Prob(F-statistic)     :  1.219e-292
# S.E. of regression  :      26.717                Log likelihood        :  -21326.334
# Sigma-square ML     :     710.003                Akaike info criterion :   42700.669
# S.E of regression ML:     26.6459                Schwarz criterion     :   42854.744
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     t-Statistic     Probability
# ------------------------------------------------------------------------------------
#     _Global_Duration         0.44896         0.01489        30.16215         0.00000
#       _Global_french        12.80620         1.42606         8.98015         0.00000
#    _Global_hybrydowy        52.15199         3.44577        15.13506         0.00000
#      _Global_hybrydy         6.70328         2.08106         3.22108         0.00129
#        _Global_kolor         1.15643         1.52148         0.76007         0.44725
#     _Global_manicure        -3.01907         7.17940        -0.42052         0.67413
#    _Global_nadbudową         5.70260         2.16059         2.63937         0.00833
#           _Global_ze         1.18618         1.95973         0.60527         0.54503
# dolnośląskie_CONSTANT        24.91830         7.96150         3.12985         0.00176
# kujawsko-pomorskie_CONSTANT        23.02863         7.97051         2.88923         0.00388
#   lubelskie_CONSTANT        16.37344         8.06630         2.02986         0.04243
#    lubuskie_CONSTANT        25.22479         8.31574         3.03338         0.00243
# mazowieckie_CONSTANT        34.83828         7.85190         4.43692         0.00001
# małopolskie_CONSTANT        24.72974         7.90625         3.12787         0.00177
#    opolskie_CONSTANT        28.50423         8.56826         3.32672         0.00089
# podkarpackie_CONSTANT        21.12145         8.06561         2.61871         0.00886
#   podlaskie_CONSTANT        35.11066         8.62520         4.07070         0.00005
#   pomorskie_CONSTANT        28.42945         7.89432         3.60125         0.00032
# warmińsko-mazurskie_CONSTANT        21.55444         8.43782         2.55450         0.01067
# wielkopolskie_CONSTANT        20.85789         7.85691         2.65472         0.00797
# zachodniopomorskie_CONSTANT        24.97478         8.10938         3.07974         0.00208
#     łódzkie_CONSTANT        19.49572         7.99946         2.43713         0.01484
#     śląskie_CONSTANT        21.58987         7.88026         2.73974         0.00617
# świętokrzyskie_CONSTANT        19.35690         8.90607         2.17345         0.02980
# ------------------------------------------------------------------------------------
# Regimes variable: unknown
#
# REGIMES DIAGNOSTICS - CHOW TEST
#                  VARIABLE        DF        VALUE           PROB
#                  CONSTANT        15         206.831           0.0000
#               Global test        15         206.831           0.0000
#
# REGRESSION DIAGNOSTICS
# MULTICOLLINEARITY CONDITION NUMBER           53.972
#
# TEST ON NORMALITY OF ERRORS
# TEST                             DF        VALUE           PROB
# Jarque-Bera                       2     1243510.266           0.0000
#
# DIAGNOSTICS FOR HETEROSKEDASTICITY
# RANDOM COEFFICIENTS
# TEST                             DF        VALUE           PROB
# Breusch-Pagan test               23       70996.790           0.0000
# Koenker-Bassett test             23        1713.174           0.0000
# ================================ END OF REPORT =====================================

# %%
# Build full table of regression coefficients
regimes_woj_7_hyb = pd.DataFrame(
    {
        # Pull out regression coefficients and
        # flatten as they are returned as Nx1 array
        "Coeff.": hyb_model_regimes_woj_7.betas.flatten(),
        # Pull out and flatten standard errors
        "Std. Error": hyb_model_regimes_woj_7.std_err.flatten(),
        # Pull out P-values from t-stat object
        "P-Value": [i[1] for i in hyb_model_regimes_woj_7.t_stat],
    },
    index=hyb_model_regimes_woj_7.name_x
    # Round to four decimals
).round(4)
regimes_woj_7_hyb
# Out:
#                                Coeff.  Std. Error  P-Value
# dolnośląskie_CONSTANT         24.9183      7.9615   0.0018
# kujawsko-pomorskie_CONSTANT   23.0286      7.9705   0.0039
# lubelskie_CONSTANT            16.3734      8.0663   0.0424
# lubuskie_CONSTANT             25.2248      8.3157   0.0024
# mazowieckie_CONSTANT          34.8383      7.8519   0.0000
# małopolskie_CONSTANT          24.7297      7.9062   0.0018
# opolskie_CONSTANT             28.5042      8.5683   0.0009
# podkarpackie_CONSTANT         21.1215      8.0656   0.0089
# podlaskie_CONSTANT            35.1107      8.6252   0.0000
# pomorskie_CONSTANT            28.4294      7.8943   0.0003
# warmińsko-mazurskie_CONSTANT  21.5544      8.4378   0.0107
# wielkopolskie_CONSTANT        20.8579      7.8569   0.0080
# zachodniopomorskie_CONSTANT   24.9748      8.1094   0.0021
# łódzkie_CONSTANT              19.4957      7.9995   0.0148
# śląskie_CONSTANT              21.5899      7.8803   0.0062
# świętokrzyskie_CONSTANT       19.3569      8.9061   0.0298
# _Global_Duration               0.4490      0.0149   0.0000
# _Global_french                12.8062      1.4261   0.0000
# _Global_hybrydowy             52.1520      3.4458   0.0000
# _Global_hybrydy                6.7033      2.0811   0.0013
# _Global_kolor                  1.1564      1.5215   0.4473
# _Global_manicure              -3.0191      7.1794   0.6741
# _Global_nadbudową              5.7026      2.1606   0.0083
# _Global_ze                     1.1862      1.9597   0.5450

# %% [markdown]
# # Podsumowanie modeli z $R^2$

# %%
df_lam_pow = pd.DataFrame(
    [[lam_model_base_pow.r2, lam_model_base_pow.ar2], [lam_model_regimes_pow.r2, lam_model_regimes_pow.ar2], [lam_model_regimes_pow_4.r2, lam_model_regimes_pow_4.ar2]],
    index=["OLS", "OLS_Regimes (CV features = 3)", "OLS_Regimes (CV features = 4)"],
    columns=["R2", "Adj. R2"],
)

df_hyb_pow = pd.DataFrame(
    [[hyb_model_base_pow.r2, hyb_model_base_pow.ar2], [hyb_model_regimes_pow.r2, hyb_model_regimes_pow.ar2], [hyb_model_regimes_pow_7.r2, hyb_model_regimes_pow_7.ar2]],
    index=["OLS", "OLS_Regimes (CV features = 5)", "OLS_Regimes (CV features = 7)"],
    columns=["R2", "Adj. R2"],
)

df_lam_woj = pd.DataFrame(
    [[lam_model_base_woj.r2, lam_model_base_woj.ar2], [lam_model_regimes_woj.r2, lam_model_regimes_woj.ar2], [lam_model_regimes_woj_7.r2, lam_model_regimes_woj_7.ar2]],
    index=["OLS", "OLS_Regimes (CV features = 5)", "OLS_Regimes (CV features = 7)"],
    columns=["R2", "Adj. R2"],
)

df_hyb_woj = pd.DataFrame(
    [[hyb_model_base_woj.r2, hyb_model_base_woj.ar2], [hyb_model_regimes_woj.r2, hyb_model_regimes_woj.ar2], [hyb_model_regimes_woj_7.r2, hyb_model_regimes_woj_7.ar2]],
    index=["OLS", "OLS_Regimes (CV features = 5)", "OLS_Regimes (CV features = 7)"],
    columns=["R2", "Adj. R2"],
)

# %%
print('Laminacja rzęs - Regimes = Powiaty')
display(df_lam_pow)
print('Manicure hybrydowy - Regimes = Powiaty')
display(df_hyb_pow)
print('Laminacja rzęs - Regimes = Województwa')
display(df_lam_woj)
print('Manicure hybrydowy - Regimes = Województwa')
display(df_hyb_woj)
# Out:
# Laminacja rzęs - Regimes = Powiaty
#                                      R2   Adj. R2
# OLS                            0.576692  0.575407
# OLS_Regimes (CV features = 3)  0.655387  0.596476
# OLS_Regimes (CV features = 4)  0.656735  0.597698
# Manicure hybrydowy - Regimes = Powiaty
#                                      R2   Adj. R2
# OLS                            0.235254  0.234241
# OLS_Regimes (CV features = 5)  0.375415  0.333687
# OLS_Regimes (CV features = 7)  0.377276  0.335360
# Laminacja rzęs - Regimes = Województwa
#                                      R2   Adj. R2
# OLS                            0.583116  0.581216
# OLS_Regimes (CV features = 5)  0.617387  0.611211
# OLS_Regimes (CV features = 7)  0.618430  0.611674
# Manicure hybrydowy - Regimes = Województwa
#                                      R2   Adj. R2
# OLS                            0.235254  0.234241
# OLS_Regimes (CV features = 5)  0.271627  0.268238
# OLS_Regimes (CV features = 7)  0.274326  0.270627
